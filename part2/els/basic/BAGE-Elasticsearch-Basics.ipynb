# %% [markdown]
# # Install Java (OSK)

# %% [markdown]
# at least Java 7.
# recommended Oracle JDK version 1.8.0_73
# JRE download: http://www.oracle.com/technetwork/java/javase/downloads/jre8-downloads-2133155.html  (2016.07.18)

# %% [markdown]
# # Install homebrew (OSX)

# %% [raw]
# #http://brew.sh/index_ko.html
# /usr/bin/ruby -e "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/master/install)"

# %% [markdown]
# # Install Elasticsearch server (Ubuntu, CentOS, Windows)
# https://www.elastic.co/downloads/elasticsearch

# %% [markdown]
# # Install Elasticsearch server (OSX)
# https://gist.github.com/jpalala/ab3c33dd9ee5a6efbdae

# %% [raw]
# # install elasticsearch by homebrew
# brew update
# brew install elasticsearch

# %% [raw]
# # get info
# brew info elasticsearch

# %% [markdown]
# # Install Elasticsearch client Python packages

# %% [raw]
# pip install elasticsearch # base package
# pip install elasticsearch_dsl # high level package

# %% [markdown]
# # Start/Stop Elasticsearch server
# https://robots.thoughtbot.com/starting-and-stopping-background-services-with-homebrew

# %% [raw]
# # check service info
# brew services list

# %% [raw]
# # start/stop as a service.
# brew tap homebrew/services
# brew services start elasticsearch
# brew services stop elasticsearch
#
# # start with config file path
# brew services start
# elasticsearch --config=/usr/local/etc/elasticsearch/elasticsearch.yml

# %% [markdown]
# # Check Elasticsearch server

# %% [raw]
# # check service info
# brew info elasticsearch
#
# # check config file.
# cat /usr/local/etc/elasticsearch/elasticsearch.yml
#
# # monitoring log messages.
# tail -f /usr/local/var/log/elasticsearch.log

# %% [markdown]
# # Install Python packages

# %% [raw]
# pip install elasticsearch
# pip install elasticsearch_dsl

# %% [markdown]
# # install Elasticsearch HQ (web admin plugin)

# %% [raw]
# # http://www.elastichq.org/support_plugin.html
# /usr/local/opt/elasticsearch/libexec/bin/plugin install royrusso/elasticsearch-HQ

# %% [markdown]
# # ------------------- 수업 시작 ----------------------

# %% [markdown]
# # Elasticsearch vs RDBMS
# http://www.slideshare.net/sophistlv/2-d1-elasticsearch
# - Index = Database
# - Type = Table
# - Mapping = Schema
# - Document = Row
# - _id = Primary Key
# - shard = pyisical partition

# %% [markdown]
# # Elasticsearch Reference (v2.3)
# https://www.elastic.co/guide/en/elasticsearch/reference/current/index.html

# %% [markdown]
# # Change node name

# %% [raw]
# # vi /usr/local/etc/elasticsearch/elasticsearch.yml 하여 node.name 부분 주석 제거
#
# brew services stop elasticsearch
# brew services start elasticsearch
#
# # Elasticsearch HQ 에서 노드 이름 변경 확인

# %% [markdown]
# # Docs Samples

# %%
import pickle
import pprint

docs = pickle.load(open('famous_saying.pkl', 'rb'))
print(len(docs))
pprint.pprint(docs[:10])
# Out:
# 1000
# [{'content': '오직 남들을 위하여 산 인생만이 가치 있는 것이다.', 'speaker': '아인슈타인'},
#  {'content': '울지 않는 청년은 야만인이요 웃지 않는 노인은 바보다.', 'speaker': '조지 산타아나'},
#  {'content': '사랑은 고생을 면할 수가 없다.그러나 잊을 수 있는 능력이 있다.', 'speaker': '디즈레일리'},
#  {'content': '사람을 알려면 그의 지갑,쾌락,그리고 불평을 보라.', 'speaker': '탈무드'},
#  {'content': '최고급 회개란 과거의 죄를 청산하고 똑바로 행동하는 것이다.', 'speaker': '윌리암 제임스'},
#  {'content': '생활의 기술이란 우리의 환경에 대한 계속적인 적응을 의미한다.', 'speaker': '오카쿠라 카쿠조'},
#  {'content': '은혜를 입은 자는 잊지말아야 하고 베푼자는 기억하지 말아야 한다.', 'speaker': '피레 찰론'},
#  {'content': '현대화 보다 더 고상한 것이 있다.그것은 바로 영원한 것이다.', 'speaker': '솔로몬 세치터'},
#  {'content': '당신은 항상 영웅이 될수 없다.그러나 항상 사람은 될수 있다.', 'speaker': '괴테'},
#  {'content': '어떤 가치있는 행동을 하지 아니한 날,그날은 잃은 날이다.', 'speaker': '자콥 보바트'}]

# %% [markdown]
# # Connection

# %%
# create global connection
from elasticsearch_dsl.connections import connections
connections.create_connection(hosts='localhost', timeout=30)  # global elasticsearch connection

from elasticsearch import Elasticsearch
es = Elasticsearch(hosts='localhost', timeout=30)
print(connections, es)
# Out:
# <elasticsearch_dsl.connections.Connections object at 0x106a7f1d0> <Elasticsearch([{'host': 'localhost'}])>

# %% [markdown]
# # Type Mapping (Table Schema)

# %%
# noinspection PyUnresolvedReferences
from elasticsearch_dsl import analysis, DocType, String, Date, Integer, analyzer


class FamousSaying(DocType): # Type(Mapping) Class
    # analyzer
    __bage_char_filter = analysis.char_filter('bage_char_filter', 'html_strip', escaped_tags=[])
    __bage_token_filter = analysis.token_filter('bage_token_filter', 'stop', stopwords=[])
    bage_token_analyzer = analyzer('token_analyzer',
                                  type='custom',
                                  char_filter=['html_strip', __bage_char_filter],
                                  tokenizer='whitespace',  # tokens by whitespace
                                  filter=['lowercase', __bage_token_filter],
                              )
    index = 'famous_saying_v2'  # Index(database) for searching
    doc_type = 'famous_saying'  # Type(table)

    # mapping
    speaker = String(index='not_analyzed')
    content = String(analyzer=bage_token_analyzer)
    content_length = Integer(index='not_analyzed')

    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.meta.index = self.index
        hash_key = '%s#%s' % (kwargs['speaker'], kwargs['content'])
        self.meta.id = hashlib.md5(hash_key.encode('utf8')).hexdigest()    # primary key
        self.content_length = len(kwargs['content'].split()) # additional field 
        
    @classmethod
    def set_indexing_mode(cls, indexing_mode=True):
        if indexing_mode:
            cls.index = 'famous_saying_v2'  # database for indexing
        else:
            cls.index = 'famous_saying_v2' # database for searching
                
    @classmethod
    def recreate_index(cls, number_of_shards=5, number_of_replicas=1):
        cls.set_indexing_mode()
        ElasticsearchUtil.recreate_index(FamousSaying, number_of_shards, number_of_replicas)

# %% [markdown]
# # Indexing (curl)
# https://www.elastic.co/guide/en/elasticsearch/reference/current/docs-index_.html

# %% [raw]
# # http://localhost:9200/INDEX/TYPE/DOC_ID
# curl -XPUT 'http://localhost:9200/famous_saying_v1/famous_saying/1?pretty=true' -d '
# {
#     "speaker" : "박혜웅",
#     "content" : "아무리 바빠도 바벨피쉬는 빠지지 말자."
# }'

# %% [markdown]
# # Indexing (python)
# https://elasticsearch-py.readthedocs.io/en/master/

# %%
doc = {"speaker" : "박혜웅", "content" : "내가 모르는 것을 아는 척하는 것도 실력이다."}
for i in range(3):
    res = es.index(index=FamousSaying.index, doc_type=FamousSaying.doc_type, body=doc)
    print(res['created'])
    
for i in range(3):
    res = es.index(index=FamousSaying.index, doc_type=FamousSaying.doc_type, id=1, body=doc)
    print(res['created'])
# Out:
# True
# True
# True
# True
# False
# False

# %% [markdown]
# # Manage with ES HQ (Web admin plugin)
# http://localhost:9200/_plugin/hq/
# - cluster diagram
# - cluster health (yellow)
# - nodes, shards, documents
# - delete index

# %% [markdown]
# # Change settings of Index (curl)

# %% [raw]
# curl -XPUT 'localhost:9200/famous_saying_v1/_settings?pretty=true' -d '
# {
#     "index" : {
#         "number_of_replicas" : 0
#     }
# }'

# %% [raw]
# curl -XPUT 'localhost:9200/famous_saying_v1/_settings?pretty=true' -d '
# {
#     "index" : {
#         "number_of_shards" : 1
#     }
# }'

# %% [markdown]
# # Manage with ES HQ
# - cluster health(green)

# %% [markdown]
# # Recreate Index

# %%
from elasticsearch_dsl import Index
import traceback

class ElasticsearchUtil(object):
    @staticmethod
    def recreate_index(type_class, number_of_shards=5, number_of_replicas=1):
        try:
            print("recreate index... '%s'" % type_class.index)
            new_index = Index(type_class.index)
            new_index.settings(
                number_of_shards=number_of_shards,
                number_of_replicas=number_of_replicas
            )
            new_index.doc_type(type_class)

            try:
                new_index.delete(ignore=404)
            except:
                pass
            new_index.create()
            print('recreate index OK')
        except:
            print(traceback.format_exc())

# %% [markdown]
# # Bulk Indexing Tip (python)
# https://www.elastic.co/guide/en/elasticsearch/reference/current/indices-update-settings.html

# %%
# befor indexing (for performance)
def before_indexing(es):
    FamousSaying.set_indexing_mode(True)
    FamousSaying.recreate_index()
    es.indices.put_settings(body={'refresh_interval': -1, 'number_of_replicas': 0}, index=FamousSaying.index)

# %% [raw]
# curl -XPUT 'localhost:9200/famous_saying_v1/_settings?pretty=true' -d '
# {
#     "index" : {"refresh_interval" : -1, "number_of_replicas" : 0}
# }'

# %%
# after indexing (for performance)
def after_indexing(es):
    es.indices.put_settings(body={'refresh_interval': '60s', 'number_of_replicas': 1}, index=FamousSaying.index)
    FamousSaying.set_indexing_mode(False)

# %% [raw]
# curl -XPUT 'localhost:9200/famous_saying_v1/_settings?pretty=true' -d '
# {
#     "index" : {"refresh_interval" : "60s", "number_of_replicas" : 1}
# }'

# %% [markdown]
# # monitoring log messages.
# tail -f /usr/local/var/log/elasticsearch.log

# %% [markdown]
# # Bulk Indexing (python)

# %%
docs
# Out:
# [{'content': '오직 남들을 위하여 산 인생만이 가치 있는 것이다.', 'speaker': '아인슈타인'},
#  {'content': '울지 않는 청년은 야만인이요 웃지 않는 노인은 바보다.', 'speaker': '조지 산타아나'},
#  {'content': '사랑은 고생을 면할 수가 없다.그러나 잊을 수 있는 능력이 있다.', 'speaker': '디즈레일리'},
#  {'content': '사람을 알려면 그의 지갑,쾌락,그리고 불평을 보라.', 'speaker': '탈무드'},
#  {'content': '최고급 회개란 과거의 죄를 청산하고 똑바로 행동하는 것이다.', 'speaker': '윌리암 제임스'},
#  {'content': '생활의 기술이란 우리의 환경에 대한 계속적인 적응을 의미한다.', 'speaker': '오카쿠라 카쿠조'},
#  {'content': '은혜를 입은 자는 잊지말아야 하고 베푼자는 기억하지 말아야 한다.', 'speaker': '피레 찰론'},
#  {'content': '현대화 보다 더 고상한 것이 있다.그것은 바로 영원한 것이다.', 'speaker': '솔로몬 세치터'},
#  {'content': '당신은 항상 영웅이 될수 없다.그러나 항상 사람은 될수 있다.', 'speaker': '괴테'},
#  {'content': '어떤 가치있는 행동을 하지 아니한 날,그날은 잃은 날이다.', 'speaker': '자콥 보바트'},
#  {'content': '좋은 일을 많이 해내려고 기다리는 사람은 하나의 좋은 일도 해낼 수가 없다.',
#   'speaker': '사무엘 존슨'},
#  {'content': '소비된 시간은 존재하고 이용된 시간은 생명이다.', 'speaker': '영'},
#  {'content': '내일의 모든 꽃은 오늘의 씨앗에 근거한 것이다.', 'speaker': '중국 속담'},
#  {'content': '죄는 취소될 수 없다.용서될 뿐이다.', 'speaker': '스트라빈스키'},
#  {'content': '자유느 획득하는 것보다 간직하는 것이 더 어렵다.', 'speaker': '컬훈'},
#  {'content': '참된 삶을 맛보지 못한 자만이 죽음을 두려워하는 것이다.', 'speaker': '제이메이'},
#  {'content': '가치있는 적이 될 수 있는 자는 화해하면 더 가치있는 친구가 될 것이다.', 'speaker': '펠담'},
#  {'content': '원인은 숨겨지지만 결과는 잘 알려진다.', 'speaker': '오비딩스'},
#  {'content': '모든 죄의 기본은 조바심과 계으럼이다.', 'speaker': '카프카'},
#  {'content': '하늘에는 입이 없으므로, 사람으로 하여금 말하게 한다.', 'speaker': '하이케이야기'},
#  {'content': '민주주의는 정지된 것이 아니라 영원히 계속되는 행진이다.', 'speaker': '루즈벨트'},
#  {'content': '금전은 무자비한 주인이지만 유익한 종이 되기도 한다.', 'speaker': '유태 격언'},
#  {'content': '힘없는 정부는 미약하고, 정의없는 힘은 포악이다.', 'speaker': '파스칼'},
#  {'content': '기회는 새와 같은것, 날아가기 전에 꼭 잡아라.', 'speaker': '스마일즈'},
#  {'content': '맹세는 말에 지나지 않고 말은 바람에 지나지 않는다.', 'speaker': '버틀러'},
#  {'content': '늑대는 이빨을 잃어도 그 천성은 잃지 않는다.', 'speaker': '풀러'},
#  {'content': '언론의 자유를 죽이는 것은 진리를 죽이는 것이다.', 'speaker': '밀턴'},
#  {'content': '성공의 비결은 목적을 향해 시종일관하는 것이다.', 'speaker': '디즈레일리'},
#  {'content': '한 가지 일을 경험하지 않으면 한 가지 지혜가 자라지 않는다.', 'speaker': '명심보감'},
#  {'content': '의인의 수고는 생명에 이르고 악인의 소득은 죄에 이른다.', 'speaker': '성경 잠언'},
#  {'content': '가장 높은 곳에 올라가려면, 가장 낮은 곳 부터 시작하라.', 'speaker': '푸블릴리우스 시루스'},
#  {'content': '가시에 찔리지 않고서는 장미꽃을 모을 수가 없다.', 'speaker': '필페이'},
#  {'content': '청년이여 일하라. 좀더 일하라. 끝까지 열심히 일하라.', 'speaker': '비스마르크'},
#  {'content': '한가한 인간은 고여 있는 물이 썩는 것과도 같다.', 'speaker': '프랑스 격언'},
#  {'content': '빈곤은 재앙이 아니라 불편이다.', 'speaker': '플로리오'},
#  {'content': '살아 있는 실패작은 죽은 걸작보다 낫다.', 'speaker': '버나드 쇼'},
#  {'content': '정직은 가장 확실한 자본이다.', 'speaker': '에머슨'},
#  {'content': '모든 일은 계획으로 시작하고, 노력으로 성취되며, 오만으로 망친다.', 'speaker': '관자'},
#  {'content': '태만을 즐기고 있을 때는 태만함을 느끼지 못한다.', 'speaker': '가스가 센안'},
#  {'content': '사업을 좌우하여라. 사업에 의해 좌우되어서는 안된다.', 'speaker': '프랭클린'},
#  {'content': '백년을 살 것처럼 일하고 내일 죽을 것처럼 기도하라.', 'speaker': '프랭클린'},
#  {'content': '부유함이 문명을 낳지는 못하나, 문명은 부유함을 낳는다.', 'speaker': '비처'},
#  {'content': '가난한 사람은 덕행으로, 부자는 선행으로 이름을 떨쳐야 한다.', 'speaker': '주베르'},
#  {'content': '시종일관하는 자는 운명을 믿고, 변덕 부리는 자는 요행을 믿는다.', 'speaker': '디즈레일리'},
#  {'content': '인간의 진정한 재산은 그가 이 세상에서 행하는 선행인 것이다.', 'speaker': '마호메트'},
#  {'content': '자신이 현명하다고 생각하고 있는 인간은 정녕 구제할 수 없는 바보이다.', 'speaker': '볼테르'},
#  {'content': '얻기 어려운 것은 시기(時期)요, 놓치기 쉬운 것은 기회이다.', 'speaker': '조광조'},
#  {'content': '누구나 오래 살기를 바란다. 그러나 누구를 막론하고 나이는 먹기 싫어한다.', 'speaker': '스위프트'},
#  {'content': '술은 인격을 비춰주는 거울이다.', 'speaker': '아르케시우스'},
#  {'content': '충실한 삶의 깊이를 아는 자는 아름다운 죽음의 가치를 안다.', 'speaker': '테오도르'},
#  {'content': '가장 훌륭한 기술, 가장 배우기 어려운 기술은 세상을 살아가는 기술이다.', 'speaker': '메이시'},
#  {'content': '여가를 활용하지 못하는 사람은 항상 여가 시간이 없다.', 'speaker': '서양 격언'},
#  {'content': '가장 최상의 길은 없다. 많은 사람이 가고 있다면 그 길이 최상이다.', 'speaker': '루신'},
#  {'content': '죽음을 두려워하는 나머지 삶을 시작조차 못하는 사람이 많다.', 'speaker': '벤다이크'},
#  {'content': '신념은 연애와 같은 것이어서 강요할 수 없는 것이다.', 'speaker': '쇼펜하우어'},
#  {'content': '속이는 말로 재물을 모으는 것은 죽음을 구하는 것이다.', 'speaker': '성경 잠언'},
#  {'content': '말이 입힌 상처는 칼이 입힌 상처보다 깁다.', 'speaker': '모르코 속담'},
#  {'content': '이해가 부족한 사람이 오해가 많은 사람보다 낫다.', 'speaker': '아나톨 프랑스'},
#  {'content': '한 시대의 철학은 다음 시대에서는 평범한 상식에 불과하다.', 'speaker': '헨리 W. 비치'},
#  {'content': '결함이 나의 출발의 바탕이고 무능이 나의 근원이다.', 'speaker': '발레리'},
#  {'content': '현실에 대한 눈은 감을수 있어도 기억에 대한 눈은 감을 수 없다.', 'speaker': '스타니스러우 J. 룩'},
#  {'content': '생각이 깊지 못한 사람은 항상 입을 놀린다.', 'speaker': '호머'},
#  {'content': '부지런한 바보만큼 이웃을 괴롭히는 자는 없다.', 'speaker': 'H. 가이야'},
#  {'content': '무지함을 두려워 말라. 거짓 지식을 두려워하라.', 'speaker': '파스칼'},
#  {'content': '자신의 행동이 빗나간 사람일수록 맨 먼저 남을 모략한다.', 'speaker': '몰리에르'},
#  {'content': '인간이란 생각하는 것이 적으면 적을수록 많이 지껄여댄다.', 'speaker': '몽테스키외'},
#  {'content': '남은 많이 용서하되 자신은 결코 용서하지 말라.', 'speaker': '푸블릴리우스 시루스'},
#  {'content': '사람은 자기 일보다 남의 일을 더 잘알고 더 잘 판단한다.', 'speaker': '테렌티우스'},
#  {'content': '눔을 감아라. 그럼 너는 너 자신을 볼 수 있으리라.', 'speaker': '버틀러'},
#  {'content': '군자는 의리에 밝고, 소인은 이익에 밝다.', 'speaker': '세익스피어'},
#  {'content': '눈물을 흘리면서 빵을 먹어보지 못한 사람은 인생의 참맛을 알 수 없다.', 'speaker': '괴테'},
#  {'content': '굳은 결심은 가장 유용한 지식이다.', 'speaker': '나폴레옹'},
#  {'content': '선을 행하는 데는 나중이라는 말이 필요없다.', 'speaker': '괴테'},
#  {'content': '학문의 최대의 적은 자기 마음속에 있는 유혹이다.', 'speaker': '처칠'},
#  {'content': '기대하지 않는 자는 실망하지도 않을 것이다.', 'speaker': '울거터'},
#  {'content': '좋은 밤을 찾다가 좋은 낮을 잃어버리는 사람들이 많다.', 'speaker': '네델란드 격언'},
#  {'content': '악은 쾌락 속에서도 고통을 주지만 덕은 고통속에서도 위안을 준다.', 'speaker': '콜튼'},
#  {'content': '환락은 망상 위에 세울 수 있으나, 행복은 진리 위에만 세워진다.', 'speaker': '니꼬라'},
#  {'content': '어느날 갑자기 착한 사람이 되거나 악인이 되는 사람은 없다.', 'speaker': '시드니'},
#  {'content': '많은 벗을 가진 사람은 한 사람의 진실한 벗을 가질 수 없다.', 'speaker': '아리스토텔레스'},
#  {'content': '지성인은 자기의 마음으로 자기 자신을 망보는 사람이다.', 'speaker': '까뮈'},
#  {'content': '어떠한 충고일지라도 길게 말하지 말라.', 'speaker': '호라티우스'},
#  {'content': '남자는 마음으로 늙고 여자는 얼굴로 늙는다.', 'speaker': '서양속담'},
#  {'content': '친구를 얻는 유일한 방법은 스스로 완전한 친구가 되는 것이다.', 'speaker': '에머슨'},
#  {'content': '지식과 목재는 세파에 시달리지 아니하면 많이 애용될 수가 없다.', 'speaker': '올리버 웬델 홈즈'},
#  {'content': '거룩하고 즐겁고 활기차게 살아라. 믿음과 열심에는 피곤과 짜증이 없다.', 'speaker': '어네스트 홈즈'},
#  {'content': '아무리 화려한 궁전이라도 초라한 내 집만한 곳은 없다.', 'speaker': '페인'},
#  {'content': '하나의 모범은 천 마디의 논쟁보다 더 가치 있는 것이다.', 'speaker': '토마스 카알라일'},
#  {'content': '당신은 의지의 주인이 되라. 그리고 당신은 양심의 노예가 되라.', 'speaker': '유태 속담'},
#  {'content': '작은 도끼라도 찍고 찍으면 큰 참나무는 넘어진다.', 'speaker': '세익스피어'},
#  {'content': '행동을 초래시키지 않는 생각, 그것은 생각이 아니라 공상이다.', 'speaker': '엘리자 램브 마틴'},
#  {'content': '민주주의의 모든 질병은 더 많은 민주주의에 의해서 치료될 수 있다.', 'speaker': '알프레드 스미스'},
#  {'content': '용기가 없는 사람에게는 어떤 좋은 것도 생기지 않는다.', 'speaker': '마르쿠스 아우렐리우스'},
#  {'content': '오직 바보나 죽은 자만이 절대로 자기의 의견을 변화시키지 않는다.', 'speaker': '제임스 럿셀 로우웰'},
#  {'content': '큰 시련은 큰 의무를 완수하게 만드는 것이다.', 'speaker': '톰슨'},
#  {'content': '배운 사람은 항상 자기 속에 재산이 있다.', 'speaker': '필래드라스'},
#  {'content': '적당주의자가 되지 말라. 그것은 세상에서 가장 위험한 것이다.', 'speaker': '휴그 왈폴'},
#  {'content': '자연은 하나님의 작품이요. 예술은 사람의 작품이다.', 'speaker': '롱펠로우'},
#  {'content': '편견이란 실효성이 없는 의견이다.', 'speaker': '암브로스 빌'},
#  {'content': '선한 사람이 되라. 그러면 세상은 선한 세상이 될 것이다.', 'speaker': '힌두교 속담'},
#  {'content': '인류를 위해 사는 것은 자기의 이름을 위해 사는 것보다 훌륭한 것이다.', 'speaker': '바첼 린드세이'},
#  {'content': '작지만 청결한 것은 큰 것이요. 크지만 불결한 것은 작은 것이다.', 'speaker': '바이'},
#  {'content': '기쁨을 주는 사람만이 더 많은 기쁨을 즐길 수 있다.', 'speaker': '알렉산더 듀마'},
#  {'content': '너 자신을 다스려라. 그러면 당신은 세계를 다스릴 것이다.', 'speaker': '중국 속담'},
#  {'content': '작은 구멍 하나가 큰 배를 침몰시키는 것이다.', 'speaker': '에프라임 도마라츠키'},
#  {'content': '성실하지 못한 사람은 위대한 것들을 생산할 수가 없다.', 'speaker': '제임스 럿셀 로우웰'},
#  {'content': '목표를 보는 자는 장애물을 겁내지 않는다.', 'speaker': '한나 모어'},
#  {'content': '산을 옮기는 사람은 작은 돌맹이부터 옮긴다.', 'speaker': '중국 속담'},
#  {'content': '세상이 당신에게 준 것보다 더 많이 세상에게 주라.', 'speaker': '헨리 포드'},
#  {'content': '험담은 세 사람을 죽인다. 말하는 자, 험담의 대상자, 듣는자.', 'speaker': '미드라쉬'},
#  {'content': '핑계를 잘 대는 사람은 거의 좋은 일을 하나도 해내지 못한다.', 'speaker': '벤자민 프랭클린'},
#  {'content': '겸손이 없다면 당신은 인생의 가장 기본적인 교훈도 배울 수가 없다.', 'speaker': '존 톰슨'},
#  {'content': '작은 성공을 만족스럽게 생각하는 사람은 큰 성공을 얻지 못한다.', 'speaker': '제세 메서 게만'},
#  {'content': '나는 내 운명의 주인이요. 나는 내 마음의 선장이다.', 'speaker': '윌리암 어네스트 헨리'},
#  {'content': '존재하는 것을 변화시키는 것은 성숙하게 만드는 것이다.', 'speaker': '헨리 버그슨'},
#  {'content': '인격은 당신의 아이들에게 남겨줄 수 있는 최대의 유산이다.', 'speaker': '아놀드 그라소우'},
#  {'content': '과도한 재산을 소유하게 되었을 때보다 더 시련을 당하게 되는 적은 없다.', 'speaker': '레우 왈레이스'},
#  {'content': '행동가처럼 생각하라. 그리고 생각하는 사람처럼 행동하라.', 'speaker': '헨리 버그슨'},
#  {'content': '소유물의 부족은 개선할 수 있으나 영혼의 가난은 해결하기 쉬운 것이 아니다.', 'speaker': '몽테뉴'},
#  {'content': '당신의 인생은 당신이 하루종일 무슨 생각을 하는지에 달려있다.', 'speaker': '에머슨'},
#  {'content': '하나님 앞에서는 울어라. 그러나 사람들 앞에서는 웃어하.', 'speaker': '유태 속담'},
#  {'content': '인내하라.경험하라.조심하라. 그리고 희망을 가져라.', 'speaker': '조셉 에디슨'},
#  {'content': '위대한 사람은 절대로 기회가 부족하다고 불평하지 않는다.', 'speaker': '에머슨'},
#  {'content': '위대한 사람은 목적을, 소인들은 공상을 가지고 있다.', 'speaker': '와싱턴 어빙'},
#  {'content': '사람의 척도는 그가 불행을 얼마나 잘 이겨내는지에 달려있다.', 'speaker': '프르다크'},
#  {'content': '돈으로 살 수 있는 행복이라 불리는 상품은 없다.', 'speaker': '헨리 밴 다이크'},
#  {'content': '세상에서 가장 아름다운 것은 세상 그 자체이다.', 'speaker': '스티븐슨'},
#  {'content': '일은 인간생활의 피할 수 없는 조건이며, 인간 복지의 참된 근원이다.', 'speaker': '톨스토이'},
#  {'content': '좋은 전쟁 또는 나쁜 평화는 없다.', 'speaker': '프랭클린'},
#  {'content': '일은 인류를 사로잡는 모든 질환과 비참을 치료해 주는 주요한 치료제이다.', 'speaker': '칼라일'},
#  {'content': '최대다수의 최대행복은 도덕과 입법의 초석이다.', 'speaker': '벤담'},
#  {'content': '전쟁에선 어느 편이 스스로를 승자라고 부를지라도 승리자는 없고 모두 패배자 뿐이다.',
#   'speaker': '챔벌린'},
#  {'content': '전쟁에서는 오직 한 번 죽지만 정치에서는 여러번 죽는다.', 'speaker': '처칠'},
#  {'content': '일을 몰고 가라. 그렇지 않으면 일이 너를 몰고 갈 것이다.', 'speaker': '프랭클린'},
#  {'content': '위대한 것 치고 정열이 없이 이루어진 것은 없다.', 'speaker': '에머슨'},
#  {'content': '인생을 해롭게 하는 비애를 버리고 명랑한 기질을 간직하라.', 'speaker': '세익스피어'},
#  {'content': '우유부단한 것만이 습관으로 되어 있는 사람보다 더 비참한 사람은 없다.', 'speaker': '제임스'},
#  {'content': '인간은 아직까지도 모든 컴퓨터중에서 가장 훌륭한 컴퓨터이다.', 'speaker': '케네디'},
#  {'content': '우리의 거의 모든 삶이 어리석은 호기심에 낭비되고 있다.', 'speaker': '보들레르'},
#  {'content': '조용한 물이 깊이 흐른다.', 'speaker': '릴리'},
#  {'content': '다른 사람들을 비난하려고 생각하기 전에 자기 자신을 추분이 살펴보아야 한다.', 'speaker': '몰리에르'},
#  {'content': '천재란 인내에 대한 위대한 자질 이외에는 아무것도 아니다.', 'speaker': '뷰퐁'},
#  {'content': '시간을 선택하는 것은 시간을 절약하는 것이다.', 'speaker': '베이컨'},
#  {'content': '친구들을 불신한다는 것은 그들에게 속은 것보다 더 수치스러운 일이다.', 'speaker': '로셔푸코'},
#  {'content': '맹세는 말에 지나지 않고, 말은 바람에 지나지 않는다.', 'speaker': '버틀러'},
#  {'content': '어리석은 자는 수치스러운 일을 할 때에도 그것이 언제나 그의 의무라고 선포한다.',
#   'speaker': '버나드쇼'},
#  {'content': '시간을 잘 맞춘 침묵은 말보다 더 좋은 웅변이다.', 'speaker': '터퍼'},
#  {'content': '청년기는 대실수이다. 장년기는 투쟁이다. 그리고 노년기는 후회이다.', 'speaker': '디즈레일리'},
#  {'content': '절제는 모든 미덕의 진주고리를 이어주는 비단의 실이다.', 'speaker': '홀'},
#  {'content': '삶은 순간들의 연속이다. 한순간,한순간을 사는 것이 성공하는 겄이다.', 'speaker': '켄트'},
#  {'content': '우리의 인내가 우리의 힘보다 더 많은 것을 성취할 것이다.', 'speaker': '버크'},
#  {'content': '인간은 패배하였을 때 끝나는 것이 아니다.포기 했을 때 끝나는 것이다.', 'speaker': '닉슨'},
#  {'content': '어느 사회에서나 유아들에게 우유를 먹이는 것보다 더 좋은 투자는 없다.', 'speaker': '처칠'},
#  {'content': '좋은 친구는 건강에도 좋다.', 'speaker': '시라손'},
#  {'content': '힘으로서 사람을 복종시키지 말고 덕으로서 사람을 복종시켜라.', 'speaker': '맹자'},
#  {'content': '많은 사람이 충고를 받지만, 오직 현명한 자만이 충고의 덕을 본다.', 'speaker': '푸블릴리우스'},
#  {'content': '군자의 사귐은 담담함이 물과 같고, 소인의 사귐은 달콤함이 단술과 같다.', 'speaker': '장자'},
#  {'content': '악은 선을 인식시키고 고통은 기쁨을 느끼게 한다.', 'speaker': '그리스도'},
#  {'content': '잔잔한 바다에서는 좋은 뱃사공이 만들어지지 않는다.', 'speaker': '영국속담'},
#  {'content': '확실한 벗은 불확실한 처지에 있을 때 알려진다.', 'speaker': '시세로'},
#  {'content': '사랑은 사람들을 치료한다. 사랑을 받는 사람,사랑을 주는 사람 할 것이 없이.', 'speaker': '메닝거'},
#  {'content': '말로하는 사랑은 쉽게 외면할수 있으나 행동으로 보여주는 사라은 저항할 수가 없다.',
#   'speaker': '무니햄'},
#  {'content': '성공적인 결혼이란 매일같이 개축해야 하는 건물과 같은 것이다.', 'speaker': '모로아'},
#  {'content': '사랑하고 나서 잃는 것은 전혀 사랑하지 않았던 것보다 더 낫다.', 'speaker': '테니슨'},
#  {'content': '소인은 특별한 것에 관심이 있고, 위인은 평범한 것에 관심이 있다.', 'speaker': '허버트'},
#  {'content': '용기는 대단히 중요하다. 근육과 같이 사용함으로써 강해진다.', 'speaker': '고든'},
#  {'content': '사랑하고 사랑받는 것은 태양을 양쪽에서 쪼이는 것과 같다.', 'speaker': '비스코트'},
#  {'content': '지성이란 그것을 갖고 있지 않는 사람에게는 보이지 않는다.', 'speaker': '쇼펜하우어'},
#  {'content': '분노는 바보들의 가슴속에서만 살아간다.', 'speaker': '아인슈타인'},
#  {'content': '너의 의무를 다하라. 그리고 나머지는 하나님께 맡겨라.', 'speaker': '코네일'},
#  {'content': '나의 음악은 어린 아이들과 동물들이 가장 잘 이해한다.', 'speaker': '스트라빈스키'},
#  {'content': '당신이 누군가를 배반한다면,당신은 또한 당신 자신을 배반하는 셈이다.', 'speaker': '싱거'},
#  {'content': '가정은 삶의 보물상자가 되어야 한다.', 'speaker': '코르뷔제'},
#  {'content': '지식인은 지금까지 일어났던 일을 안다. 천재는 앞으로 일어날 일을 안다.', 'speaker': '치아디'},
#  {'content': '서툰 의사는 한번에 한 사람을 해치지만, 서툰 교사는 130명을 해친다.', 'speaker': '보이어'},
#  {'content': '태만이란 약한 마음을 가진 사람의 유일한 피난처이다.', 'speaker': '체스터필드'},
#  {'content': '권세가 인간을 교만으로 이끌어갈 때,시가 그에게 한계를 상기시켜준다.', 'speaker': '케네디'},
#  {'content': '무거운 마음을 가지고 가벼운 시를 즐길 수 없다.', 'speaker': '베이커'},
#  {'content': '사악은 언제나 미덕보다 더 쉽다. 왜냐하면 사악은 모든일에 지름길을 택하기 때문이다.',
#   'speaker': '존스'},
#  {'content': '훌륭한 삶에는 세 가지 요소가 있다. 즉 배우는 일,돈 버는 일,무엇인가 하고 싶은일.',
#   'speaker': '몰리'},
#  {'content': '패배를 극복하는 법을 배워야 한다. 그럴때에 당신의 인격이 향상된다.', 'speaker': '닉슨'},
#  {'content': '호기심이란 무지의 고백인데 그것은 의도적이며 당당하며 열렬하다.', 'speaker': '루빈슈타인'},
#  {'content': '여행이란 젊은이들에게는 교육의 일부이며 연장자들에겐 경험의 일부이다.', 'speaker': '베이컨'},
#  {'content': '덕이 없는 아름다움은 향기 없는 꽃이다.', 'speaker': '프랑스 격언'},
#  {'content': '무관심 때문에 사람은 실제로 죽기전에 죽어버린다.', 'speaker': '위젤'},
#  {'content': '긍지는 인간이 입을 수 있는 가장 훌륭한 갑옷이다.', 'speaker': '제롬'},
#  {'content': '신기한 말을 하는 것이 귀함이 아니라 실행함이 귀하다.', 'speaker': '이태백'},
#  {'content': '의복에만 마음이 쏠리는 것은 마음과 인격이 잠든 탓이다.', 'speaker': '에머슨'},
#  {'content': '누구든지 크나큰 시련을 당하기 전에는 참다운 인간이 못된다.', 'speaker': '레오랄지이'},
#  {'content': '위대한 사람은 모두가 겸손하다.', 'speaker': '레싱'},
#  {'content': '장점과 훌륭한 예의는 어디서나 번영할 것이다.', 'speaker': '체스터필드'},
#  {'content': '좋은 가문에서 태어나는 것은 바람직한 일이다. 그러나 그 영광은 조상의 것이다.',
#   'speaker': '플루타르쿠스'},
#  {'content': '충고자는 아무리 신랄하여도 결코 해를 끼치지 않는다.', 'speaker': '푸블릴리우스 시루스'},
#  {'content': '먹는 것은 자신을 즐겁게 하기 위함이요. 입는 것은 남을 즐겁게 하기 위함이다.',
#   'speaker': '프랭클린'},
#  {'content': '신사를 만드는 것은 옷이 아니다.', 'speaker': '영국속담'},
#  {'content': '재산가들 중에는 상식을 가진 자가 드물다.', 'speaker': '유베날리스'},
#  {'content': '행복이란 불만에 자기가 속지 않으면 된다.', 'speaker': '러셀'},
#  {'content': '진주를 간직하고 있는 것은 병든 궁이다.', 'speaker': '세드'},
#  {'content': '적은 것을 적다고 하지 말며 천한 것을 천하게 여기지 말라.', 'speaker': '소자'},
#  {'content': '인간은 사회적 동물이다.', 'speaker': '아리스토텔레스'},
#  {'content': '가시나무를 심는 자는 장미를 기대해서는 안된다.', 'speaker': '필페이'},
#  {'content': '모든 날 중 가장 완전히 잃어버린 날은 웃지 않은 날이다.', 'speaker': '샹포르'},
#  {'content': '근심은 세월을 거치지 않고 백발과 노령을 가져온다.', 'speaker': '영국속담'},
#  {'content': '권리는 어느 곳에나 도리를 벗어난 곳에서는 존재할 수 없다.', 'speaker': '파크'},
#  {'content': '공손과 인간성과의 관계는, 따스함과 밀초와의 관계와 같다.', 'speaker': '쇼펜하우어'},
#  {'content': '이기는 것이 중요한 것이 아니다. 어떻게 노력하는가가 문제이다.', 'speaker': '쿠베르탕'},
#  {'content': '두사람의 개성의 만남은 두가지 화학물질의 접촉과 같다. 반응이 있으면 둘 다 변화한다.',
#   'speaker': '융'},
#  {'content': '참고 버티라. 그 고통은 차츰차츰 너에게 좋은 것으로 변할 것이다.', 'speaker': '오비디우스'},
#  {'content': '오래 가는 행복은 정직한 것 속에서만 발견할 수 있다.', 'speaker': '리히텐베르히'},
#  {'content': '넌 자신을 누구에겐가 필요한 존재로 만들라. 누구에게든 인생을 고되게 만들지 말라.',
#   'speaker': '에머슨'},
#  {'content': '종소리처럼 맑고 분명해라.', 'speaker': '레이'},
#  {'content': '존재하는 모든 훌륭한 것은 독창력의 열매이다.', 'speaker': '밀'},
#  {'content': '인내는 쓰다. 그러나 그 열매는 달다.', 'speaker': '루소'},
#  {'content': '훌륭한 말은 훌륭한 무기이다.', 'speaker': '풀러'},
#  {'content': '어린이가 없는 곳에 천국은 없다.', 'speaker': '스윈번'},
#  {'content': '"말하자마자 행동하는 사람, 그것이 가치있는 사람이다.', 'speaker': '엔니우스'},
#  {'content': '대화시의 신중은 웅변보다 더 중요하다.', 'speaker': '그라시안'},
#  {'content': '양심은 어떠한 과학의 힘보다도 강하고 현명하다.', 'speaker': '라데이러'},
#  {'content': '어리석은 짓을 삼가는 것이 지혜의 입문이다.', 'speaker': '호라티우스'},
#  {'content': '교육의 목표는 지식의 증진과 진리의 씨부리기이다.', 'speaker': '케네디'},
#  {'content': '미소,악수,혹은 호의로운 눈총 등 무었인가를 남에게 동냥할 필요가 없는 인간은 없다.',
#   'speaker': '댈버그'},
#  {'content': '아예 배우지 않느니 보다는 늦으나마 배우는 편이 낫다.', 'speaker': '클레오 불루스'},
#  {'content': '생명이 있는 한,사람은 무었인가 바랄수 있다.', 'speaker': '세네카'},
#  {'content': '자기 일을 멸시하는 자는 먹을 양식과 싸운다.', 'speaker': '스퍼전'},
#  {'content': '습관은 제二의 천성으로 제一의 천성을 파괴한다.', 'speaker': '파스칼'},
#  {'content': '사람의 천성과 직업이 맞을때 행복하다.', 'speaker': '베이컨'},
#  {'content': '사람은 돈지갑은 가난해도,정신적으로는 긍지를 가질 수 있다.', 'speaker': '메이슨'},
#  {'content': '한나라의 진정한 재산은 땀흘려 일하는 부지런한 주민의 수에 있다.', 'speaker': '나폴레옹'},
#  {'content': '사랑은 인생의 소금이다.', 'speaker': '셰필드'},
#  {'content': '시련이란 진리로 통하는 으뜸가는 길이다.', 'speaker': '바이런'},
#  {'content': '사랑없이 사는 것은 정말로 사는 것이 아니다.', 'speaker': '몰리에르'},
#  {'content': '내기는 탐욕의 아들이며,부정의 형제이며,불행의 아버지이다.', 'speaker': '워싱턴'},
#  {'content': '자신의 주인이 되는 자는 곧 다른 사람들의 주인이 될 것이다.', 'speaker': '풀러'},
#  {'content': '희망은 가난한 인간의 빵이다.', 'speaker': '탈레스'},
#  {'content': '빈부강약을 막론하고 일하지 않는자를 배척하라.', 'speaker': '루소'},
#  {'content': '시간을 이용할줄 아는 사람은 하루를 사흘로 통용한다.', 'speaker': '영국속담'},
#  {'content': '모든 일은 어려운 고비를 넘겨야 쉬워진다.', 'speaker': '풀러'},
#  {'content': '우리는 지성적으로 되기 위해 많은 대가를 치른다.', 'speaker': '에우리피데스'},
#  {'content': '정신으로 창조된 것은 물질보다 한결 생명적이다.', 'speaker': '보들레르'},
#  {'content': '검약은 훌륭한 소득이다.', 'speaker': '에라스무스'},
#  {'content': '지혜는 고통을 통해서 생긴다.', 'speaker': '아에스킬루스'},
#  {'content': '좋은 나무는 좋은 열매를 맺는다.', 'speaker': '랭런드'},
#  {'content': '말도 행동이고 행동도 말의 일종이다.', 'speaker': '에머슨'},
#  {'content': '중간이 가장 안전할 것이다.', 'speaker': '오비디우스'},
#  {'content': '행동에 부주의하지 말며,말에 혼동되지 말며,생각에 방황하지 말라.', 'speaker': '마르크스 아우렐리우스'},
#  {'content': '모든 개량과 진보의 근본은 근로이다.', 'speaker': '카네기'},
#  {'content': '충고는 좀처럼 환영받지 못한다.', 'speaker': '체스터필드'},
#  {'content': '탐구정신은 우리가 살고 있는 시대의 위대한 특징이다.', 'speaker': '풀'},
#  {'content': '지구상에는 인간이외는 위대한 것이 없다.인간에게는 지성이외엔 훌륭한 것이 없다.', 'speaker': '헤밀턴'},
#  {'content': '험한 언덕을 오르려면 처음에는 서서희 걸어야 한다.', 'speaker': '세익스피어'},
#  {'content': '논리와 상식은 다르다.', 'speaker': '하버드'},
#  {'content': '많은 사물중에서 가운데가 제일이다.내 위치도 가운데가 되게 하라.', 'speaker': '포킬리데스'},
#  {'content': '자기 자신을 예찬하는 자는 신의 미움을 받는다.', 'speaker': '클레멘스'},
#  {'content': '악은 선을 인식시키고 고통은 기쁨을 느끼게 한다.', 'speaker': '그리스도'},
#  {'content': '마땅히 행할 길을 아이에게 가르쳐라.그리하면 늙으도 그것을 떠나지 않으리라.', 'speaker': '성경'},
#  {'content': '근심은 미를 훔치는 도둑이다.', 'speaker': '마미언'},
#  {'content': '한치의 기쁨마다 한자의 고민이 있다.', 'speaker': '베넘'},
#  {'content': '인간은 환경을 창조하고 환경은 인간을 창조한다.', 'speaker': '밝은 사회'},
#  {'content': '아름다운 것은 선하고 선한 자는 곧 아름다워진다.', 'speaker': '삽포'},
#  {'content': '공정하고 바른데는 근거를 두었다면 긍지보다 이익을 주는 것은 좀처럼 없다.', 'speaker': '밀턴'},
#  {'content': '시간은 언제까지든 당신을 기다리는 것은 아니다.', 'speaker': '짐멜'},
#  {'content': '인생은 불확실한 항해이다.', 'speaker': '셰익스피어'},
#  {'content': '아름다움이란 경솔한 사람이 그릇생각하듯 보이는 그대로 외관만의 치레는 아니다.', 'speaker': '스펜스'},
#  {'content': '창조는 고민속에서 나오고 발전은 고생 속에서 움튼다.', 'speaker': '밝은 사회'},
#  {'content': '소비된 시간은 존재하고 이용된 시간은 생명이다.', 'speaker': '영'},
#  {'content': '내가 아직 살아있는 동안에는 나로 하여금 헛되이 살지 않게 하라.', 'speaker': '에디슨'},
#  {'content': '정직한 노동은 사랑스런 얼굴을 낳는다.', 'speaker': '대커'},
#  {'content': '인간은 이성적 동물이다.(세네카)2proo.', 'speaker': '세네카'},
#  {'content': '모범은 모든 사람이 읽을 수 있는 교훈이다.', 'speaker': '웨스트'},
#  {'content': '일은 시작할 때가 언제나 가장 좋다.', 'speaker': '파스칼'},
#  {'content': '인류의 목적은 휴식이 아니다.그것은 지적이며 도덕적인 완성이다.', 'speaker': '르낭'},
#  {'content': '공손이란 가장 친절한 방법으로 가장 친절한 것을 향하고 말하는 것이다.', 'speaker': '루이전'},
#  {'content': '행실은 각자가 자기의 이미지를 보여주는 거울이다.', 'speaker': '괴테'},
#  {'content': '다른 사람을 지배하려는 사람은,먼저 자기 자신의 주인이 되어야 한다.', 'speaker': '매신저'},
#  {'content': '위대한 것을 멸시하고,과도함 보다는 중용을 택하는 것이 군자의 특징이다.', 'speaker': '세네카'},
#  {'content': '목적 없이 존재하는 것은 아무 것도 없다.', 'speaker': '보들레르'},
#  {'content': '전력을 다해서 시간에 대항하라.', 'speaker': '톨스토이'},
#  {'content': '인생에서 중요한 법칙은 만사에 중용을 지키는 일이다.', 'speaker': '테렌티우스'},
#  {'content': '다정하고 조용한 말은 힘이 있다.', 'speaker': '에머슨'},
#  {'content': '돈이 있어도 이상이 없는 사람은 몰락의 길을 밟는다.', 'speaker': '도스도예프스키'},
#  {'content': '마음의 즐거움은 얼굴을 빛나게 하여도 마음의 근심은 심령을 상하게 하느니라.', 'speaker': '성경'},
#  {'content': '평온한 마음으로 아껴 생활하는 것이 사람에게 큰 부이다.', 'speaker': '루크레티우스'},
#  {'content': '버들가지는 약하나 다른 재목을 묵는다.', 'speaker': '허버트'},
#  {'content': '사람의 잘못은 좀처럼 자신에게는 나타나지 않는다.', 'speaker': '셰익스피어'},
#  {'content': '부당한 이득을 얻지말라.그것은 손해와 같은 것이다.', 'speaker': '헤시오도스'},
#  {'content': '근로가 잠들면 빈곤은 창으로 들어온다.', 'speaker': '라이닉'},
#  {'content': '자기가 할 수 있는 일은 남에게 밀지 말라.', 'speaker': '제퍼슨'},
#  {'content': '최초의 큰 웃음보다는 마지막의 미소가 오히려 났다.', 'speaker': '영국속담'},
#  {'content': '쓴 맛을 보기 전에 단 맛을 보아서는 안된다.', 'speaker': '고울딤 헴'},
#  {'content': '조금 알기 위해서 많이 공부해야 한다.', 'speaker': '몽테스키외'},
#  {'content': '인생의 참된 목적은 영원히 생명을 깨닫는데 있다.', 'speaker': '톨스토이'},
#  {'content': '상식은 그렇게 흔한 것이 아니다.', 'speaker': '볼테르'},
#  {'content': '훌륭한 충고보다 값진 선물은 없다.', 'speaker': '에라스무스'},
#  {'content': '사자라 할지라도 파리들로 부터 자기 몸을 방어해야 한다.', 'speaker': '독일격언'},
#  {'content': '내 자신의 무식을 아는 것은 지식에로의 첫걸음이다.', 'speaker': '바이런'},
#  {'content': '가장 훌륭한 예언은 상식,즉 우리의 원래의 지혜이다.', 'speaker': '에우리피데스'},
#  {'content': '행복하게 산다는 것은 마음의 평온함을 뜻한다.', 'speaker': '시세로'},
#  {'content': '자기 자신을 아는 것은 참된 진보이다.', 'speaker': '안데르센'},
#  {'content': '배우라.비교하라.사실을 수입하라.', 'speaker': '파플로프'},
#  {'content': '할 수 있는 한 훌륭한 인생을 만들라.인생은 짧고 곧 지나간다.', 'speaker': '오울디즈'},
#  {'content': '군자는 기회가 없다고 불평하지 않는다.', 'speaker': '에머슨'},
#  {'content': '두 사람의 머리는 한 사람의 머리보다 낫다.', 'speaker': '헤이우드'},
#  {'content': '탐구하여 찾아질 수 없을 정도로 어려운 문제는 존재하지 않는다.', 'speaker': '티랜티우스'},
#  {'content': '인간은 천에 따라서 자기 옷을 지어야 한다.', 'speaker': '내쉬'},
#  {'content': '아이들에게는 비평보다도 귀감이 필요하다.', 'speaker': '쥬벨'},
#  {'content': '큰 나무는 바람을 많이 받는다.', 'speaker': '카네기'},
#  {'content': '담화는 마음의 보다 즐거운 향연이다.', 'speaker': '호메로스'},
#  {'content': '천재응 1퍼센트의 영감이요. 99퍼센트는 노력이다.', 'speaker': '보비'},
#  {'content': '뿌리가 튼튼해야 열매가 많다.', 'speaker': '용비어천가'},
#  {'content': '서투런 의사소통은,훌륭한 예절을 망쳐버린다.', 'speaker': '메난드로스'},
#  {'content': '마음이 어진 사람은 조그마한 집에 살아도 행복하다.', 'speaker': '홍자성'},
#  {'content': '일의 기량을 닦기 위해서 가장 중요한 것은 실행과 경험이다.', 'speaker': '콜루맬라'},
#  {'content': '산 기계를 만들지 말고, 인간을 만들라.', 'speaker': '페스탈로찌'},
#  {'content': '다른 인간을 증오하는 댓가는, 자신을 더 적게 사랑하는 것이다.', 'speaker': '클리버'},
#  {'content': '안심하면서 먹는 한조각 빵이 근심하면서 먹는 잔치보다 낫다.', 'speaker': '이솝'},
#  {'content': '나는 나 자신을 빼 놓고는 모두 안다.', 'speaker': '비용'},
#  {'content': '강한 사람이란 가장 훌륭하게 고독을 견디어 낸 사람이다.', 'speaker': '쉴러'},
#  {'content': '만약 급히 서두르려면 돌아 가는 길로 가라.', 'speaker': '영국속담'},
#  {'content': '덕이 없는 아름다움은 향기 없는 꽃이다.', 'speaker': '프랑스 격언'},
#  {'content': '인간성 이외에는 본질적으로 진실한 것은 없다.', 'speaker': '콩트'},
#  {'content': '화가 나면 열을 세어라. 풀리지 않는 다면 백을 세어라.', 'speaker': '제퍼슨'},
#  {'content': '날이 밝기 직전에 항상 가장 어둡다.', 'speaker': '풀러'},
#  {'content': '미련한 자는 자기 행위를 바른 줄로 여긴다.', 'speaker': '성경'},
#  {'content': '모든 국가의 기초는 그 나라 젊은 이들의 교육이다.', 'speaker': '디오게네스'},
#  {'content': '인간은 신의 걸작품이다.', 'speaker': '퀼즈'},
#  {'content': '인간은 죽을 때까지 완전한 인간이 못된다.', 'speaker': '플랭클린'},
#  {'content': '자기가 가고 있는 곳을 모르는 사람은 결코 높이 향상하지 못한다.', 'speaker': '크롬웰'},
#  {'content': '진정한 벗은 제2의 자기인 것이다.', 'speaker': '아리스토텔레스'},
#  {'content': '자신을 알 수 있는 사람이야말로 진정한 현인이다.', 'speaker': '초서'},
#  {'content': '시기와 질투는 언제나 남을 쏘려다가 자신을 쏜다.', 'speaker': '맹자'},
#  {'content': '진정한 위인치고 자신을 위인으로 생각하는 자는 없다.', 'speaker': '해즐리트'},
#  {'content': '폭풍은 참나무가 더욱 뿌리를 깊게 박도록 한다.', 'speaker': '허버트'},
#  {'content': '모범은 훈화보다 유효하다.', 'speaker': '영국속담'},
#  {'content': '즐거움에 찬 얼굴은 한접시의 물로도 연회를 만들 수 있다.', 'speaker': '허버트'},
#  {'content': '대화는 학생들의 실험실이요, 작업장이다.', 'speaker': '에머슨'},
#  {'content': '미지를 향해 출발하는 사람은 누구나 외로운 모험에 만족해야 한다.', 'speaker': '지드'},
#  {'content': '노동은 생명이요, 광명이다.', 'speaker': '위고'},
#  {'content': '기와 한장 아껴서 대들보 썩는다.', 'speaker': '한국속담'},
#  {'content': '소인은 특별한 것에 관심이 있고, 위인은 평범한 것에 관심이 있다.', 'speaker': '허버트'},
#  {'content': '하나의 작은 꽃을 만드는 데도 오랜 세월의 노력이 필요하다.', 'speaker': '블레이크'},
#  {'content': '인간은 교육을 통하지 않고는 인간이 될 수 없는 유일한 존재이다.', 'speaker': '칸트'},
#  {'content': '노년은 청춘에 못지 않은 좋은 기회이다.', 'speaker': '롱펠로우'},
#  {'content': '한 손으로 다른 손을 씻고, 두 손으로 얼굴을 씻는다.', 'speaker': '플로리오'},
#  {'content': '우리의 거의 모든 삶이 어리석은 호기심에 낭비되고 있다.', 'speaker': '보들레르'},
#  {'content': '풍랑은 항상 능력있는 항해자 편이다.', 'speaker': '기번'},
#  {'content': '말 한 마디가 세계를 지배한다.', 'speaker': '쿠크'},
#  {'content': '우리들은 감탄과 희망과 사랑으로 산다.', 'speaker': '워즈워드'},
#  {'content': '단 하나의 하늘에 올려진 고마워하는 생각이 완전한 기도이다.', 'speaker': '레싱'},
#  {'content': '말만 하고 행동하지 않는 사람은 잡초로 가득 찬 정원과 같다.', 'speaker': '하우얼'},
#  {'content': '지식이 깊은 사람은 시간의 손실을 가장 슬퍼한다.', 'speaker': '단테'},
#  {'content': '미는 내부의 생명으로부터 나오는 빛이다.', 'speaker': '켈러'},
#  {'content': '자신이 자신의 지휘관이다.', 'speaker': '플라우투스'},
#  {'content': '오늘 가장 좋게 웃는 자는 역시 최후에도 웃을 것이다.', 'speaker': '니체'},
#  {'content': '영혼이 깃든 청춘은 그렇게 쉽사리 사라지지 않는다.', 'speaker': '카로사'},
#  {'content': '노령에 활기를 주는 진정한 방법은, 마음의 청춘을 연장하는 것이다.', 'speaker': '콜린즈'},
#  {'content': '결백한 자와 미인은, 시간 이외에는 적이 없다.', 'speaker': '예이츠'},
#  {'content': '너의 위대한 조상을 본받아 행동하라.', 'speaker': '드라이든'},
#  {'content': '지혜의 가장 명백한 징조는 쉴새없이 명랑한 것이다.', 'speaker': '몽테뉴'},
#  {'content': '아름다운 것！ 그것은 마음의 눈으로 보여지는 미(美)이다.', 'speaker': '주베르'},
#  {'content': '많은 사람이 충고를 받지만, 오직 현명한 자만이 충고의 덕을 본다.', 'speaker': '푸블릴리우스'},
#  {'content': '정당하게 사는 자에게는 어느 곳이든 안전하다.', 'speaker': '에픽테투스'},
#  {'content': '지혜는 간혹 누더기 가면을 덮어쓰고 있다.', 'speaker': '스타티우스'},
#  {'content': '창조적인 예술가는 그 전의 작품에 만족하지 않기 때문에 다음 작품을 만든다.',
#   'speaker': '쇼스타코비치'},
#  {'content': '위기의 시기에는 가장 대담한 방법이 때로는 가장 안전하다.', 'speaker': '키신저'},
#  {'content': '친구란 누구나 이미 알고 있는 원수에 불과하다', 'speaker': '커트 코베인'},
#  {'content': '지금은 명언할 수가 없다', 'speaker': ''},
#  {'content': '인생의 목적은 성숙하지 않기 위해 싸우는 것이다', 'speaker': '딕 워트하이머'},
#  {'content': '아무 말도 하지 않는 사람 중에 침묵하는 사람은 거의 없다.(진정한 침묵은 말하지 않는 것 이상이다.)',
#   'speaker': '토머스 닐'},
#  {'content': '성공한 사람이 될 수 있는데 왜 평범한 이에 머무르려 하는가?', 'speaker': '베르톨트 브레히트'},
#  {'content': '질서있는 모습이 아름다움을 결정한다', 'speaker': '펄 벅'},
#  {'content': '그 누구도 혼자서는 지혜로울 수 없다', 'speaker': '플라우투스'},
#  {'content': '권위에만 의존하는 윤리체계는 없다', 'speaker': 'A. J. 에이어'},
#  {'content': '그 어떤 현인도 젊어지기를 바라지 않는다', 'speaker': '조나단 스위프트'},
#  {'content': '나의 집이란 장소가 아니라, 사람들이다', 'speaker': '로이스 맥마스터 부욜'},
#  {'content': '사람은 실패가 아니라 성공하기 위해 태어난다', 'speaker': '헨리 데이비드 소로우'},
#  {'content': '슬픔의 유일한 치료제는 행동이다', 'speaker': '조지 헨리 루이스'},
#  {'content': '음악은 본질적으로 쓸모가 없다. 인생처럼', 'speaker': '조지 산타야나'},
#  {'content': '1파운드의 용기는 행운 1톤의 가치를 지닌다', 'speaker': '제임스 A. 가필드'},
#  {'content': '이 책은 매우 필요한 간극을 메운다', 'speaker': '모지즈 하다스'},
#  {'content': "책을 영화로 판단하지 마라.('책을 겉표지로 판단하지 말라'의 패러디)", 'speaker': 'J. W. 이건'},
#  {'content': '낮은 목소리로 말하고, 천천히 말하고, 너무 많이 말하지 말라', 'speaker': '존 웨인'},
#  {'content': '누구에게나 친구는 어느 누구에게도 친구가 아니다', 'speaker': '아리스토텔레스'},
#  {'content': '인격은 그 사람의 운명이다', 'speaker': '헤라클레이토스'},
#  {'content': '인터넷은 시간 낭비이다', 'speaker': '윌리엄 깁슨'},
#  {'content': '용기는 기도를 마친 두려움이다', 'speaker': '도로시 버나드'},
#  {'content': '키스하는 두 사람은 항상 물고기처럼 보인다', 'speaker': '앤디 워홀'},
#  {'content': '반성하지 않는 삶은 살 가치가 없다', 'speaker': '소크라테스'},
#  {'content': '희망만이 인생을 유일하게 사랑하는 것이다', 'speaker': '앙리 프레데릭 아미엘'},
#  {'content': '친구는 제 2의 자신이다', 'speaker': '아리스토텔레스'},
#  {'content': '민주 국가의 기본은 자유다', 'speaker': '아리스토텔레스'},
#  {'content': '많은 공부와 지식이 곧 지혜로 연결되는 것은 아니다', 'speaker': '헤라클레이토스'},
#  {'content': '실패가 불가능한 것처럼 행동하라', 'speaker': '도로시아 브랜드'},
#  {'content': '명언은 힘들 때 도움이 된다.', 'speaker': ''},
#  {'content': '웃음 없는 하루는 낭비한 하루다', 'speaker': '찰리 채플린'},
#  {'content': '음식은 가장 원시적인 형태의 위안거리다', 'speaker': '쉴라 그레이엄'},
#  {'content': '돈은 사랑의 핏줄이자 전쟁의 핏줄', 'speaker': '토마스 풀러'},
#  {'content': '낭비한 시간에 대한 후회는 더 큰 시간 낭비이다', 'speaker': '메이슨 쿨리'},
#  {'content': '건강한 신체에 건강한 정신이 깃든다', 'speaker': '유베날리스'},
#  {'content': '나는 망명자가 어떻게 희망의 꿈을 먹고 사는지 안다', 'speaker': '아이스킬로스'},
#  {'content': '그들은 정복할 수 있다고 생각하는 자를 정복할 수 있다', 'speaker': '베르길리우스'},
#  {'content': '일을 즐기면 일의 완성도가 높아진다', 'speaker': '아리스토텔레스'},
#  {'content': '진실은 순수하기가 힘들고, 결코 단순하지 않다', 'speaker': '오스카 와일드'},
#  {'content': '말 적은 이가 제일 좋은 사람이다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '인생은 밀림 속의 동물원이다', 'speaker': '피터 드 브리스'},
#  {'content': '무한한 돈은 전쟁의 핏줄이 된다', 'speaker': '키케로'},
#  {'content': '실패는 우리가 어떻게 실패에 대처하느냐에 따라 정의됩니다', 'speaker': '오프라 윈프리'},
#  {'content': '인간이란 습관들이기 나름인가보다!', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '전체는 부분의 합보다 크다', 'speaker': '아리스토텔레스'},
#  {'content': '세기의 사랑일지라도 참고 견뎌내야 한다.', 'speaker': '코코) 샤넬'},
#  {'content': '스스로에게는 부자인 양, 친구들에게는 빈자인 양 행동하라', 'speaker': '유베날리스'},
#  {'content': '인간은 바라는 것을 기꺼이 믿는다', 'speaker': '율리우스 카이사르'},
#  {'content': '한 순간을 위해 내가 가진 모든 것을. (한 순간만 더 살수 있다면 내가 가진 모든 것을 내놓을텐데) (유언 - 번역자)',
#   'speaker': '엘리자베스 1세'},
#  {'content': '잘못된 음식이란 것은 없다', 'speaker': '션 스튜어트'},
#  {'content': '오늘은 사사건건 부딪치네요', 'speaker': '시드 비셔스'},
#  {'content': '내가 꿈꾸는 것은 바로 균형의 예술이다', 'speaker': '앙리 마티스'},
#  {'content': '절약하지 않는 자는 고통받게 될 것이니라', 'speaker': '공자'},
#  {'content': '인간에게 유일한 위대함은 죽지 않는 것이다', 'speaker': '제임스 딘'},
#  {'content': '말이 아니라, 일이 사랑의 증거다', 'speaker': '작자 미상'},
#  {'content': '명예를 잃는다면 무엇이 남는가?', 'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '독재는 신념의 힘을 꺾지 못한다', 'speaker': '헬렌 켈러'},
#  {'content': '참을성이 있는 사람이 화를 냈을 때는 조심해야 한다', 'speaker': '존 드라이든'},
#  {'content': '그 자상한 학생은 명언을 줄줄이 말했다.', 'speaker': ''},
#  {'content': '신체와 정신의 건강을 지켜라', 'speaker': '클레오불로스'},
#  {'content': '나는 깊숙히 얄팍한 사람이다', 'speaker': '앤디 워홀'},
#  {'content': '인생은 과감한 모험이던가, 아니면 아무 것도 아니다', 'speaker': '헬렌 켈러'},
#  {'content': '죄의식을 동반한 즐거움이 가져다 주는 기쁨은 짧다', 'speaker': '에우리피데스'},
#  {'content': '유머가 아예 없다면 인생을 불가능으로 바꾼다', 'speaker': '꼴레뜨'},
#  {'content': '모든 미덕은 올바른 행위를 통해 요약되어 나타난다', 'speaker': '아리스토텔레스'},
#  {'content': '가장 큰 죄악은 허세 부리는 것이다', 'speaker': '커트 코베인'},
#  {'content': '자기보다 못한 자를 벗으로 삼지 말라. (無友不如己者 / 무우불여기자)', 'speaker': '공자'},
#  {'content': '일 분 전만큼 먼 시간은 없다', 'speaker': '짐 비숍'},
#  {'content': '우리는 오로지 사랑을 함으로써 사랑을 배울 수 있다', 'speaker': '아이리스 머독'},
#  {'content': '부드러운 자 만이 언제나 진실로 강한 자다', 'speaker': '제임스 딘'},
#  {'content': '앞날을 결정짓고자 하면 옛것을 공부하라', 'speaker': '공자'},
#  {'content': '욕망은 인간의 본질이다', 'speaker': '바뤼흐 스피노자'},
#  {'content': '젊음은 알지 못한 것을 탄식하고 나이는 하지 못한 것을 탄식한다', 'speaker': '앙리 에스티엔'},
#  {'content': '그것을 증명한 사람을 믿으라. 전문가를 믿으라', 'speaker': '베르길리우스'},
#  {'content': '때로는 살아있는 것조차도 용기가 될 때가 있다', 'speaker': '세네카'},
#  {'content': '병원은 아프러 가는 곳이 아니다', 'speaker': '사무엘 골드윈'},
#  {'content': '세상의 유일한 기쁨은 시작하는 것이다', 'speaker': '체사레 파베세'},
#  {'content': '모든 인간은 선천적으로 지식을 희구한다', 'speaker': '아리스토텔레스'},
#  {'content': '지나간 슬픔에 새로운 눈물을 낭비하지 말라', 'speaker': '에우리피데스'},
#  {'content': '남들이 단순하게 살 수 있도록 단순하게 살라', 'speaker': '마하트마 간디'},
#  {'content': '시간 엄수는 비즈니스의 영혼이다', 'speaker': '토마스 할리버튼'},
#  {'content': '사람을 존경하라, 그러면 그는 더 많은 일을 해 낼 것이다', 'speaker': '제임스 오웰'},
#  {'content': '공포를 느껴라, 그리고 그래도 도전하라', 'speaker': '수잔 제퍼스'},
#  {'content': '사랑은 우리가 기꺼이 피우는 폭발하는 시가이다', 'speaker': '린다 배리'},
#  {'content': '교육은 노후를 위한 최상의 양식이다', 'speaker': '아리스토텔레스'},
#  {'content': '시간은 우리를 변화시키지 않는다. 시간은 단지 우리를 펼쳐 보일 뿐이다', 'speaker': '막스 프리쉬'},
#  {'content': '긍정적 사고만큼 나를 우울하게 만드는 일은 없다', 'speaker': '폴 퍼셀'},
#  {'content': '전쟁이 한물 갔거나 인간이 한물 갔다', 'speaker': '버크민스터 풀러'},
#  {'content': '읽는 것 만큼 쓰는 것을 통해서도 많이 배운다', 'speaker': '액톤 경'},
#  {'content': '사랑의 첫 번째 의무는 상대방에 귀 기울이는 것이다', 'speaker': '폴 틸리히'},
#  {'content': '이 책의 앞표지와 뒤표지는 너무 멀리 떨어져 있다', 'speaker': '앰브로즈 비어스'},
#  {'content': '시간은 환상이다. 점심시간은 두 배로 그렇다', 'speaker': '더글러스 애덤스'},
#  {'content': '내 일은 게임, 그것도 아주 중요한 게임이다', 'speaker': '모리츠 코르넬리스 에셔'},
#  {'content': '죽으면 만사 청산이다.(죽으면 모든 빚이 저절로 청산된다.)', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '죽음은 독재보다 나은, 더 가벼운 운명이다', 'speaker': '아이스킬로스'},
#  {'content': '작품을 보면 그것을 만든 장인을 알아볼 수 있다', 'speaker': '장 드 라퐁텐'},
#  {'content': '자부심은 작은 사람들을 위한 신의 선물이다', 'speaker': '브루스 바튼'},
#  {'content': '최고의 증거는 단연 경험이다', 'speaker': '프랜시스 베이컨'},
#  {'content': '말이 아니라 행동이 나를 대변할 것이다', 'speaker': '존 플레쳐'},
#  {'content': '흰 머리가 지혜를 낳는 건 아니다', 'speaker': '메난드로스'},
#  {'content': '무엇을 잘 하는 것은 시간낭비일 때가 많다', 'speaker': '로버트 바이른'},
#  {'content': '우리는 영원불멸하다는 것을 느끼고 안다', 'speaker': '바뤼흐 스피노자'},
#  {'content': '내 친구들이여, 세상에 친구란 없다네.', 'speaker': '코코) 샤넬'},
#  {'content': '나에게 충격적인 것이란 없소. 난 과학자니까', 'speaker': '해리슨 포드'},
#  {'content': '그냥 운동해라. 재미를 느껴라. 경기를 즐겨라', 'speaker': '마이클 조던'},
#  {'content': '지혜 없는 힘은 그 자체의 무게로 쓰러진다', 'speaker': '호라티우스'},
#  {'content': '바쁜 벌은 슬퍼할 시간이 없다', 'speaker': '윌리엄 블레이크'},
#  {'content': '기회는 자기 소개서를 보내지 않는다', 'speaker': '작자 미상'},
#  {'content': '자연과 조화롭게 살아가는 것이 삶의 목적이다', 'speaker': '제노'},
#  {'content': '진실은 죽어가는 자의 입술 위에 앉아 있다', 'speaker': '매츄 아널드'},
#  {'content': '전 아내를 무시하는 경향이 있었어요', 'speaker': '우디 알렌'},
#  {'content': '스포츠는 과거의 혼돈에 질서를 부여한다', 'speaker': '앤소니 스타'},
#  {'content': '촛불을 끄면 모든 여자들은 아름답게 보인다', 'speaker': '플루타르코스'},
#  {'content': '나는 신실하지 않으며, 심지어 이렇게 말하는 이 순간에도 그렇다', 'speaker': '쥘 르나르'},
#  {'content': '인내는 쓰지만 그 열매는 달다', 'speaker': '아리스토텔레스'},
#  {'content': '침묵은 오해하기 쉬운 글과 같다', 'speaker': '알프레드 안젤로 아타나시오'},
#  {'content': '시간은 너무 없고 할 일도 너무 없다', 'speaker': '오스카 레반트'},
#  {'content': '여윈 자유는 살찐 노예보다 낫다', 'speaker': '존 레이'},
#  {'content': '직업은 삶의 근간이다', 'speaker': '프레드리히 니체'},
#  {'content': '남의 말을 열심히 들어주다가 해고당한 사람은 없다', 'speaker': '캘빈 쿨리지'},
#  {'content': '내일에는 미래가 더 나아질 것이다', 'speaker': '댄 퀘일'},
#  {'content': '돈만으로도 세상은 돌아간다', 'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '병에 걸리기 전까지는 건강이 얼마나 중요한지 모른다', 'speaker': '토마스 풀러'},
#  {'content': '땅은 진정 최고의 예술이다', 'speaker': '앤디 워홀'},
#  {'content': '남자의 가장 훌륭한 재산은 공감해주는 아내다', 'speaker': '에우리피데스'},
#  {'content': '내가 죽었다는 보도는 과장이었다.(마크 트웨인이 죽었다는 보도가 나온 후에 한 말)',
#   'speaker': '마크 트웨인'},
#  {'content': '섹스는 역사상 가장 아무 것도 아닌 일이다', 'speaker': '앤디 워홀'},
#  {'content': '슬픔은 한결같은 사람에게 흔들림을 가르쳐준다', 'speaker': '소포클레스'},
#  {'content': '지속적인 긍정적 사고는 능력을 배가시킨다', 'speaker': '콜린 파월'},
#  {'content': '집으로 가지 않는 것은 이미 죽음이나 마찬가지다', 'speaker': 'E. 캐서린 토블러'},
#  {'content': '누군가를 사랑한다는 것은 자신을 그와 동일시 하는 것이다', 'speaker': '아리스토텔레스'},
#  {'content': '우리는 너무 많이 생각하고 너무 적게 느낀다', 'speaker': '찰리 채플린'},
#  {'content': '작은 변화가 일어날 때 진정한 삶을 살게 된다', 'speaker': '레프 톨스토이'},
#  {'content': '낡은 외투를 그냥 입고 새 책을 사라', 'speaker': '오스틴 펠프스'},
#  {'content': '참 음악이란. 세상만사 너머 마법과 같은 것!', 'speaker': '조앤 K. 롤링'},
#  {'content': '많이 읽어라. 그러나 많은 책을 읽지는 마라', 'speaker': '벤자민 프랭클린'},
#  {'content': '나의 패션 취향은 간지럽지 않은 것이 기본이다', 'speaker': '길다 래드너'},
#  {'content': '인생은 용서 속의 모험이다', 'speaker': '노먼 커즌즈'},
#  {'content': '지식은 사랑이요, 빛이며, 통찰력이다', 'speaker': '헬렌 켈러'},
#  {'content': '젊은 날의 의무는 부패에 맞서는 것이다', 'speaker': '커트 코베인'},
#  {'content': '여름에는 노래가 절로 나온다', 'speaker': '윌리엄 카를로스 윌리엄스'},
#  {'content': '사람들이 원하는 모든 것은 자신의 얘기를 들어줄 사람이다', 'speaker': '휴 엘리어트'},
#  {'content': '고결한 생각은 고상한 언어로 표현해야 한다', 'speaker': '아리스토파네스'},
#  {'content': '정직만큼 풍요로운 유산은 없다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '패션이란 결코 새로운 것이 없고, 다 헌 것이다', 'speaker': '제프리 초서'},
#  {'content': '최고의 아이디어는 공동의 자산이다', 'speaker': '세네카'},
#  {'content': '바그너의 음악은 듣기보단 괜찮다', 'speaker': '에드가 윌슨 나이'},
#  {'content': '위대한 업적은 대개 커다란 위험을 감수한 결과이다', 'speaker': '헤로도토스'},
#  {'content': '생선과 손님은 3일이 지나면 냄새를 풍긴다', 'speaker': '벤자민 프랭클린'},
#  {'content': '욕망하는 자는 늘 가난하다', 'speaker': '클라우디아누스'},
#  {'content': '희망은 어떤 상황에서도 필요하다', 'speaker': '사무엘 존슨'},
#  {'content': '사랑은 무엇보다도 자신을 위한 선물이다', 'speaker': '장 아누이'},
#  {'content': '우리는 평화롭게 살기 위해 전쟁을 치른다', 'speaker': '아리스토텔레스'},
#  {'content': '여자는 (생물학적 나이보다) 자격에 걸맞는 나이를 갖는다. (가브리엘', 'speaker': '코코) 샤넬'},
#  {'content': '모든 예술은 자연의 모방이다', 'speaker': '세네카'},
#  {'content': '아이디어란 상상력을 통해 얻은 구원한다', 'speaker': '프랭크 로이드 라이트'},
#  {'content': '죄를 미워하되 죄인은 사랑하라', 'speaker': '마하트마 간디'},
#  {'content': '나는 나의 몸을 경외한다', 'speaker': '헨리 데이비드 소로우'},
#  {'content': '적에게서조차 배울 수 있다', 'speaker': '오비디우스'},
#  {'content': '나는 대중의 편이다. 어쩔 수 없다', 'speaker': '찰리 채플린'},
#  {'content': '내가 끔찍한 골칫덩이가 될까 두려워', 'speaker': '이디스 시트웰'},
#  {'content': '먼저 오는 자가 먼저 먹는다', 'speaker': '아이크 폰 레프코우'},
#  {'content': '사람들이 생각을 안 하니 지도자들은 얼마나 운이 좋은가', 'speaker': '아돌프 히틀러'},
#  {'content': '정의의 칼에는 칼집이 없다', 'speaker': '앙트완 드 리베랄'},
#  {'content': '스스로 존경하면 다른 사람도 그대를 존경할 것이니라', 'speaker': '공자'},
#  {'content': '부는 많은 걱정거리를 해결해 준다', 'speaker': '메난드로스'},
#  {'content': '사랑하는 것은 천국을 살짝 엿보는 것이다', 'speaker': '카렌 선드'},
#  {'content': '천사도 가기 두려워 하는 곳에 바보가 달려들다.(하룻강아지 범 무서운 줄 모른다.)',
#   'speaker': '알렉산더 포프'},
#  {'content': '허물이 있다면, 버리기를 두려워 말라', 'speaker': '공자'},
#  {'content': '인간은 살아있기 위해 무언가에 대한 열망을 간직해야 한다', 'speaker': '마가렛 딜란드'},
#  {'content': '이른 아침은 입에 황금을 물고 있다', 'speaker': '벤자민 프랭클린'},
#  {'content': '인생은 겸손에 대한 오랜 수업이다', 'speaker': '제임스 M. 배리'},
#  {'content': '교육이 거둘 수 있는 최고의 성과는 관용이다', 'speaker': '헬렌 켈러'},
#  {'content': '나이가 성숙을 보장하지는 않는다', 'speaker': '라와나 블랙웰'},
#  {'content': '닫혀있기만 한 책은 블록일 뿐이다', 'speaker': '토마스 풀러'},
#  {'content': '나는 시종일관 그것의 일부를 읽는다', 'speaker': '사무엘 골드윈'},
#  {'content': '노여움이 일면, 그 결과를 생각하라', 'speaker': '공자'},
#  {'content': '책 없는 방은 영혼 없는 육체와도 같다', 'speaker': '키케로'},
#  {'content': '좋은 디자인이 고장난 비즈니스 모델을 고칠 수는 없다', 'speaker': '제프리 빈'},
#  {'content': '우둔함은 영원하나 무지는 고칠 수 있다', 'speaker': '돈 우드'},
#  {'content': '벗이 먼 곳에서 찾아오면 또한 즐겁지 아니한가 (有朋自遠方來 不亦樂乎 / 유붕자원방래 불역락호)',
#   'speaker': '공자'},
#  {'content': '가난은 인격의 스승이다', 'speaker': '안티파네스'},
#  {'content': '인기란? 명예의 잔돈이다', 'speaker': '빅터 위고'},
#  {'content': '아무런 위험을 감수하지 않는다면 더 큰 위험을 감수하게 될 것이다', 'speaker': '에리카 종'},
#  {'content': '우리 안에는 활기와 강력한 욕정이 자리잡고 있다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '내가 미래를 보았는데, 별 볼일 없어', 'speaker': '로버트 풀포드'},
#  {'content': '이제 기도해 잊고 용서하라', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '가장 잘 통치할 수 있는 자가 통치해야 한다', 'speaker': '아리스토텔레스'},
#  {'content': '수명을 늘리려면 식사를 줄여라', 'speaker': '벤자민 프랭클린'},
#  {'content': '들어 옮길 수 있는 양보다 많이 먹지 말라', 'speaker': '미스 피기'},
#  {'content': '의심스럽거든 진실을(의심스러움을 그대로) 말해라', 'speaker': '마크 트웨인'},
#  {'content': '인생에 대해 내가 말할 수 있는 전부는, 오 하나님, 즐기라는 거다!', 'speaker': '밥 뉴하트'},
#  {'content': '제우스신은 모든 인간의 계획을 성취시키지 않는다', 'speaker': '호메로스'},
#  {'content': '오늘날엔 저급한 음악만 돈이 된다', 'speaker': '프레드리히 니체'},
#  {'content': '겨울에는 1마일도 2마일이 된다', 'speaker': '조지 허버트'},
#  {'content': '가난은 모든 악의 근원이다', 'speaker': '조지 버나드 쇼'},
#  {'content': '당신은 지체할 수도 있지만 시간은 그러하지 않을 것이다', 'speaker': '벤자민 프랭클린'},
#  {'content': '투표는 총알보다 강하다', 'speaker': '에이브러햄 링컨'},
#  {'content': '그 책의 내용은 역사 속 위인들의 명언으로 가득해.', 'speaker': ''},
#  {'content': '지나치게 왕성한 생각은 사고가 아니다', 'speaker': '시어도어 로스케'},
#  {'content': '인생이 어떻든 상관없이 인간은 복수를 꿈꾼다', 'speaker': '폴 고갱'},
#  {'content': '모든 실수가 어리석은 것이라 말해선 안된다', 'speaker': '키케로'},
#  {'content': '주제를 이해하라. 그러면 할 말이 떠오를 것이다', 'speaker': '카토'},
#  {'content': '시련을 겪어야만 한다면 차라리 극한의 시련을 겪자', 'speaker': '사디'},
#  {'content': '친구는 모든 것을 나눈다', 'speaker': '플라톤'},
#  {'content': '침묵은 그 어떤 노래보다 더 음악적이다', 'speaker': '펄 벅'},
#  {'content': '거짓말도 충분히 자주 하면 진실이 된다', 'speaker': '레닌'},
#  {'content': '좋은 음식은 좋은 대화로 끝이 난다', 'speaker': '조프리 네이어'},
#  {'content': '돈을 받는 모든 직업은 마음을 빼앗고 타락시킨다', 'speaker': '아리스토텔레스'},
#  {'content': '우리는 우리가 아는 것만 볼 수 있다', 'speaker': '요한 볼프강 폰 괴테'},
#  {'content': '논쟁은 마지막에 발생한다', 'speaker': '성 아우구스티누스'},
#  {'content': '화려함의 극치! 뉴욕! 미국!', 'speaker': '찰리 채플린'},
#  {'content': '자리를 박차고 해병대로 오라!', 'speaker': '존 웨인'},
#  {'content': '어둠 속에서는 모든 고양이가 회색이다.(만물은 밤에는 비슷하게 보인다.)',
#   'speaker': '벤자민 프랭클린'},
#  {'content': '책과 그늘진 장소여…', 'speaker': '존 윌슨'},
#  {'content': '인생은 다만 한 통의 살구 씨일 뿐이다', 'speaker': '로드니 데인저필드'},
#  {'content': '그의 말에는 명언이 많이 들어있다.', 'speaker': ''},
#  {'content': '정성을 다하는 것이 곧 천도(天道)다. (지성이면 감천이다.)', 'speaker': '맹자'},
#  {'content': '오늘 방과 후에, 명언들을 몇 가지 더 찾아봐야지!', 'speaker': ''},
#  {'content': '(소유권을 주장하기보다) 실제 소유하고 있는 것이 중요하다', 'speaker': '콜리 시버'},
#  {'content': '가장 현명한 사람은 자신만의 방향을 따른다', 'speaker': '에우리피데스'},
#  {'content': '죽음은 인간이 받을 수 있는 축복 중 최고의 축복이다', 'speaker': '소크라테스'},
#  {'content': '나는 보기 위해 눈을 감는다', 'speaker': '폴 고갱'},
#  {'content': '대학은 아이디어를 얻으러 가는 곳이 아니다', 'speaker': '헬렌 켈러'},
#  {'content': '가장 힘들었던 싸움은 첫 번째 아내와의 싸움이었다', 'speaker': '무하마드 알리'},
#  {'content': '지나침은 모자람만 못하다. (過猶不及 / 과유불급)', 'speaker': '공자'},
#  {'content': '좋은 집이란 구입하는 것이 아니라 만들어지는 것이어야 한다', 'speaker': '조이스 메이나드'},
#  {'content': '젊음은 반드시 칭송되는 것만큼 좋은 것은 아니다', 'speaker': '라와나 블랙웰'},
#  {'content': '양측의 의견을 모두 듣기 전에는 결정을 내리지 마라', 'speaker': '포킬리데스'},
#  {'content': '운은 계획에서 비롯된다', 'speaker': '브랜치 리키'},
#  {'content': '몸은 말로 형언할 수 없는 것을 표현한다', 'speaker': '마사 그레이엄'},
#  {'content': '명예는 방어할 필요가 없는 것이다', 'speaker': '로버트 J. 소여'},
#  {'content': '신체는 성스러운 옷이다', 'speaker': '마사 그레이엄'},
#  {'content': '신의 은총이 없었다면 나도 그렇게 되었을 것이다', 'speaker': '존 브래드포드'},
#  {'content': '글은 행위보다 오래 간다', 'speaker': '핀다로스'},
#  {'content': '가장 적은 것으로도 만족하는 사람이 가장 부유한 사람이다', 'speaker': '소크라테스'},
#  {'content': '책을 한 권만 읽는 자에게 화 있을진저!', 'speaker': '조지 허버트'},
#  {'content': '건강이 배움보다 더 가치 있다', 'speaker': '토마스 제퍼슨'},
#  {'content': '당신이 어떤 위험을 감수하냐를 보면, 당신이 무엇을 가치있게 여기는지 알 수 있다',
#   'speaker': '자넷 윈터슨'},
#  {'content': '한 사람에게서 모든 덕을 구하지 말라', 'speaker': '공자'},
#  {'content': '어떤 것들은 믿어야 볼 수 있다', 'speaker': '랄프 호지슨'},
#  {'content': '당신의 책을 읽고 무척 마음에 들었다', 'speaker': '모지즈 하다스'},
#  {'content': '건강은 단순히 병이 없는 상태가 아니다', 'speaker': '한나 그린'},
#  {'content': '하나의 진리는 명백하다. 존재하는 것은 무엇이라도 정당하다', 'speaker': '알렉산더 포프'},
#  {'content': '나는 음악이 싫다. 특히 연주될 때에는', 'speaker': '지미 듀란티'},
#  {'content': '여행은 되돌아 보았을 때에만 매력적이다', 'speaker': '폴 서룩스'},
#  {'content': '결국 모든 것은 우스개다', 'speaker': '찰리 채플린'},
#  {'content': '뭉치면 서고, 갈라지면 넘어진다', 'speaker': '이솝'},
#  {'content': '그럼, 네가 가장 좋아하는 명언은 뭐야?', 'speaker': ''},
#  {'content': '서서히 사라지기보다 한 번에 타버리는 것이 낫다', 'speaker': '커트 코베인'},
#  {'content': '누군가에게는 음식인 것이 다른 이에게는 쓴 독이다', 'speaker': '루크레티우스'},
#  {'content': '실천이 말보다 낫다', 'speaker': '벤자민 프랭클린'},
#  {'content': '제비 한 마리가 왔다고 여름이 온 것은 아니다', 'speaker': '아리스토텔레스'},
#  {'content': '사실이 드문 곳에 전문가는 많다', 'speaker': '도널드 R. 개논'},
#  {'content': '성공의 8할은 일단 출석하는 것이다', 'speaker': '우디 알렌'},
#  {'content': '그것을 경험한 자를 믿으라', 'speaker': '베르길리우스'},
#  {'content': '성공하는 것만으로는 충분치 않다. 다른 사람들이 실패해야만 한다', 'speaker': '고어 비달'},
#  {'content': '결국 누구나 어머니의 말씀을 따라 옮기게 된다', 'speaker': '번 윌리엄스'},
#  {'content': '군중은 지도자에게 새로운 힘을 준다', 'speaker': '이베니우스'},
#  {'content': '여가는 철학의 어머니다', 'speaker': '토마스 홉스'},
#  {'content': '많은 책들이 우리를 무식하게 만들고 있다', 'speaker': '볼테르'},
#  {'content': '어디를 가든지 마음을 다해 가라', 'speaker': '공자'},
#  {'content': '미래는 예전의 미래가 아니다', 'speaker': '요기 베라'},
#  {'content': '실수는 발견의 시작이다', 'speaker': '제임스 조이스'},
#  {'content': '역사에 걸쳐 여성은 익명의 존재였다', 'speaker': '버지니아 울프'},
#  {'content': '바삐 태어나지 않은 자는 바삐 죽는다', 'speaker': '밥 딜런'},
#  {'content': '능력이 부족할 수록 자만심이 더 강하다', 'speaker': '아하드 하암'},
#  {'content': '비록 태양이 사라져도, 나는 한 줄기 빛을 얻으리라', 'speaker': '커트 코베인'},
#  {'content': '예술은 당신이 일상을 벗어날 수 있는 모든 것이다', 'speaker': '앤디 워홀'},
#  {'content': '희극은 유예된 비극에 불과하다', 'speaker': '피코 아이어'},
#  {'content': '어울리는 결혼을 원한다면 대등한 사람과 하라', 'speaker': '오비디우스'},
#  {'content': '우리가 무슨 생각을 하느냐가 우리가 어떤 사람이 되는지를 결정합니다', 'speaker': '오프라 윈프리'},
#  {'content': '무릇 간결은 지혜의 본질이요', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '글은 병든 마음을 고치는 의사다', 'speaker': '아이스킬로스'},
#  {'content': '이 패션은 뒤틀어진 도둑이로구나', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '용기를 가지되 허세는 부리지 말라', 'speaker': '메난드로스'},
#  {'content': '예술은 표절 아니면 혁명이다', 'speaker': '폴 고갱'},
#  {'content': '우리의 목적은 성공이 아니라 봉사라야 한다', 'speaker': '작자 미상'},
#  {'content': '침묵은 어리석은 자들의 미덕이다.(침묵을 통해 어리석음을 드러내지 않을 수 있다.)',
#   'speaker': '프랜시스 베이컨'},
#  {'content': '우리는 자신에 대해 거짓말을 할 때 가장 큰 소리를 낸다', 'speaker': '에릭 호퍼'},
#  {'content': '성인이 된다는 것은 곧 혼자가 된다는 뜻이다', 'speaker': '쟝 로스땅'},
#  {'content': '나는 고령의 황금기에 있다', 'speaker': '벤자민 프랭클린'},
#  {'content': '인내와 지혜는 떼려야 뗄 수 없다', 'speaker': '성 아우구스티누스'},
#  {'content': '진실은 허구라기보다 모르는 것이다', 'speaker': '마크 트웨인'},
#  {'content': '인생은 집을 향한 여행이다', 'speaker': '허먼 멜빌'},
#  {'content': '나는 내 재능이 요하는 이상으로는 겸손하지 않다', 'speaker': '오스카 레반트'},
#  {'content': '내 스스로 확신한다면 나는 남의 확신을 구하지 않는다', 'speaker': '에드거 앨런 포'},
#  {'content': '야구는 신이 인간에게 준 선물이다', 'speaker': '조지 프레데릭 윌'},
#  {'content': '한 남자의 어리석은 실수는 때때로 또 다른 남자의 아내다', 'speaker': '헬렌 롤랜드'},
#  {'content': '자신이 어떤 사람이 될지에 대해 의문을 던져라, 그러나 자기 자신에 대해서는 결코 의문을 던지지 말라',
#   'speaker': '크리스틴느 보비'},
#  {'content': '한 남자의 침묵은 듣기에 좋다', 'speaker': '토마스 하디'},
#  {'content': '인내가 최상의 미덕이다', 'speaker': '카토'},
#  {'content': '겸손함은 아름다움의 요새이다.(아름다워서 받는 시기를 겸손으로 막아낼 수 있다.)',
#   'speaker': '데마데스'},
#  {'content': '날 감히 체포할 순 없어, 난 록스타니까', 'speaker': '시드 비셔스'},
#  {'content': '정직이 없다면 존엄성은 어디에 있는가?', 'speaker': '키케로'},
#  {'content': '필요하면 결코 좋은 흥정을 할 수 없다', 'speaker': '벤자민 프랭클린'},
#  {'content': '한 사람의 조국은 어디든 그가 번창하는 곳이다', 'speaker': '아리스토파네스'},
#  {'content': '이 염원을 스스로...에게 명언하다.', 'speaker': ''},
#  {'content': '한 푼 아낀 것은 한 푼 번 것이나 마찬가지다', 'speaker': '벤자민 프랭클린'},
#  {'content': '성경은 게으름뱅이에게 빵을 약속하지 않는다', 'speaker': '작자 미상'},
#  {'content': '전 시크하지 않아요. 전 절대 시크할 수 없을 거예요', 'speaker': '시드 비셔스'},
#  {'content': '정말 멋진 명언들이 많다!', 'speaker': ''},
#  {'content': '남은 것은 침묵 뿐이로다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '태어나면서부터 현명한 이는 없다', 'speaker': '미겔 데 세르반테스'},
#  {'content': '젊은이들에게 관대하라', 'speaker': '유베날리스'},
#  {'content': '열망이 능력을 가져온다', 'speaker': '레이먼드 홀리웰'},
#  {'content': '아는 것이 힘이다', 'speaker': '프랜시스 베이컨'},
#  {'content': '배운 자만이 자유롭다', 'speaker': '에픽테토스'},
#  {'content': '천재에게 조국이란 없다', 'speaker': '찰스 처칠'},
#  {'content': '자존심은 가장 고귀한 인격을 망친다', 'speaker': '클라우디아누스'},
#  {'content': '자연이 하는 일에는 쓸데 없는 것이 없다', 'speaker': '아리스토텔레스'},
#  {'content': '우리 엄마가 가장 좋아하는 헬렌 켈러의 명언을 말해줄게.', 'speaker': ''},
#  {'content': '시작이 반이다', 'speaker': '아리스토텔레스'},
#  {'content': '예절이 사람을 만든다', 'speaker': '위컴의 윌리엄'},
#  {'content': '어떤 이들은 죽은 후에야 비로소 태어난다', 'speaker': '프레드리히 니체'},
#  {'content': '저녁 식사는 사업의 윤활유다', 'speaker': '윌리엄 스토웰 경'},
#  {'content': '사람은 스스로 믿는 대로 된다', 'speaker': '안톤 체홉'},
#  {'content': '인지(認知)함은 고통 받는 것이다', 'speaker': '아리스토텔레스'},
#  {'content': '패션은 변하지만 스타일은 남는다.', 'speaker': '코코) 샤넬'},
#  {'content': '실패하는 것은 곧 성공으로 한 발짝 더 나아가는 것이다', 'speaker': '메리 케이 애쉬'},
#  {'content': '에너지는 영원한 기쁨이다', 'speaker': '윌리엄 블레이크'},
#  {'content': '성공만큼 큰 실패는 없다', 'speaker': '제럴드 내크먼'},
#  {'content': '열망하라, 구하라, 믿으라, 받으라', 'speaker': '스텔라 테릴 만'},
#  {'content': '기쁨은 사물 안에 있지 않다. 그것은 우리 안에 있다', 'speaker': '리하르트 바그너'},
#  {'content': '창의성 없는 절약은 결핍이다', 'speaker': '에이미 다사이크진'},
#  {'content': '삶이 있는 한 희망은 있다', 'speaker': '키케로'},
#  {'content': '먹는 음식이 곧 자신이다', 'speaker': '루드비히 포이에르바하'},
#  {'content': '정직이 최고의 이미지다', 'speaker': '톰 윌슨'},
#  {'content': '웃는 자가 승자일지니!', 'speaker': '메리 페티본 풀'},
#  {'content': '인생은 위험의 연속이다', 'speaker': '다이앤 프롤로브'},
#  {'content': '진실을 사랑하고 실수를 용서하라', 'speaker': '볼테르'},
#  {'content': '글은 사람이다', 'speaker': '뷔퐁'},
#  {'content': '습관보다 강한 것은 없다', 'speaker': '오비디우스'},
#  {'content': '하늘은 용기 있는 자의 편이다', 'speaker': '베르길리우스'},
#  {'content': '변화 외에 불변하는 것은 없다', 'speaker': '헤라클레이토스'},
#  {'content': '희망은 백일몽이다', 'speaker': '아리스토텔레스'},
#  {'content': '생각은 자유다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '절대 아이를 갖지 말아라. 손자손녀만 가져라', 'speaker': '고어 비달'},
#  {'content': '세상은 변하지 않는다. 우리가 변한다', 'speaker': '헨리 데이비드 소로우'},
#  {'content': '행동은 말보다 더 새빨간 거짓말을 한다', 'speaker': '캐롤린 웰스'},
#  {'content': '때 늦은 정의는 실현되지 못한 정의이다', 'speaker': '윌리엄 글래드스톤'},
#  {'content': '열정없이 사느니 차라리 죽는게 낫다', 'speaker': '커트 코베인'},
#  {'content': '아이들은 모두 이방인이다', 'speaker': '랄프 왈도 에머슨'},
#  {'content': '봄이야말로 진정한 재건주의자다', 'speaker': '헨리 팀로드'},
#  {'content': '정숙한 분위기를 유지해 주십시오', 'speaker': '호라티우스'},
#  {'content': "우리는 하느님을 믿는다'는 미국에서 가장 일반적인 명언이다.", 'speaker': ''},
#  {'content': "우리는 하느님을 믿는다'는 미국에서 가장 일반적인 명언이다.", 'speaker': ''},
#  {'content': '"우리는 하느님을 믿는다."는 미국에서 가장 일반적인 명언이다.', 'speaker': ''},
#  {'content': '사랑은 그저 미친 짓이예요', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '이성이 열정보다 앞서야 한다', 'speaker': '에피카르모스'},
#  {'content': '큰 희망이 큰 사람을 만든다', 'speaker': '토마스 풀러'},
#  {'content': '상처는 잊되, 은혜는 결코 잊지 말라', 'speaker': '공자'},
#  {'content': '편견은 분별 없는 견해다', 'speaker': '볼테르'},
#  {'content': '육체마다 예술이 있다', 'speaker': '그웬돌린 브룩스'},
#  {'content': '악을 생각하는 것은 악을 만드는 것이다', 'speaker': '프레드리히 니체'},
#  {'content': '경험은 배울 줄 아는 사람만 가르친다', 'speaker': '올더스 헉슬리'},
#  {'content': '건강식품이 나를 아프게 한다', 'speaker': '캘빈 트릴린'},
#  {'content': '하늘은 용기있는 자를 돕는다', 'speaker': '테렌스'},
#  {'content': '모든 결혼은 이교도와의 결혼이다', 'speaker': '샨탈 세이퍼스타인'},
#  {'content': '인생이란 결코 공평하지 않다. 이 사실에 익숙해져라', 'speaker': '빌 게이츠'},
#  {'content': '강력한 이유는 강력한 행동을 낳는다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '웃음은 마음의 조깅이다', 'speaker': '노먼 커즌즈'},
#  {'content': '모든 성경은 사람이 만들었다', 'speaker': '토마스 A. 에디슨'},
#  {'content': '기억은 상상력의 자양분이다', 'speaker': '에이미 탄'},
#  {'content': '웃음은 그 자체로 건강하다', 'speaker': '도리스 레싱'},
#  {'content': '행복은 우리 자신에게 달려있다', 'speaker': '아리스토텔레스'},
#  {'content': '돈이 돈을 낳는다. (돈이 돈을 번다.)', 'speaker': '존 레이'},
#  {'content': '성공이 끝은 아니다', 'speaker': '윈스턴 처칠'},
#  {'content': '지혜는 그 어떤 재산보다 더 중요하다', 'speaker': '소포클레스'},
#  {'content': '전쟁은 좋지 않다.(이 명언 저자는 남편과 아들이 미국 대통령으로 전쟁을 수행.)',
#   'speaker': '바바라 부시'},
#  {'content': '충고는 거의 환영받지 못한다', 'speaker': '체스터필드 경'},
#  {'content': '그들의 침묵은 충분한 찬사다', 'speaker': '테렌스'},
#  {'content': '지혜로운 자는 사랑하고, 다른 모든 이는 욕망할 지니', 'speaker': '아프라니우스'},
#  {'content': '신념은 감옥이다', 'speaker': '프레드리히 니체'},
#  {'content': '내가 가장 좋아하는 동물은 스테이크이다', 'speaker': '프란 레보비츠'},
#  {'content': '우아함이란 거절이다.', 'speaker': '코코) 샤넬'},
#  {'content': '여정은 (목적지로 향하는 과정이지만, 그 자체로) 보상이다', 'speaker': '스티브 잡스'},
#  {'content': '미래는 검색할 수 있는 것이 아니다', 'speaker': '윌리엄 깁슨'},
#  {'content': '인간은 실수를 저지른다. 그러나 용서하는 경우는 많지 않다', 'speaker': '프랭클린 P. 애덤스'},
#  {'content': '컴퓨터는 머저리다', 'speaker': '피터 드러커'},
#  {'content': '네 자신의 무지를 절대 과소평가하지 마라', 'speaker': '알버트 아인슈타인'},
#  {'content': '내가 있는 곳이 낙원이라', 'speaker': '볼테르'},
#  {'content': '덜 약속하고 더 해주어라', 'speaker': '톰 피터스'},
#  {'content': '브루투스, 너마저 (나를 죽이려고 들다니)', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '인생이란 네가 다른 계획을 세우느라 바쁠 때 너에게 일어나는 것이다', 'speaker': '존 레논'},
#  {'content': '신은 아비가 지은 죄에 대해 자식들을 처벌한다', 'speaker': '에우리피데스'},
#  {'content': '적을 선택하는 신중함에 있어서 지나침이란 없다', 'speaker': '오스카 와일드'},
#  {'content': '그에겐 세상에 적이라곤 한 명도 없지만 친구들 모두가 그를 싫어한다', 'speaker': '에디 캔터'},
#  {'content': '용기란, 삶이 평화를 주는 대신 강요하는 대가이다', 'speaker': '아멜리아 에어하트'},
#  {'content': '아래 있는 사람은 떨어지는 것을 겁낼 필요가 없고 낮은 곳에 있는 이는 거드름을 피울 필요가 없다',
#   'speaker': '존 버니언'},
#  {'content': '아, 이 사랑의 봄은 사월 어느 날의 변덕스런 영광을 닮았구나!', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '젊음은 경이롭다. 아이들에게 젊음을 낭비하다니 죄악이 아닐 수 없다', 'speaker': '조지 버나드 쇼'},
#  {'content': '미국인의 최대 비즈니스는 비즈니스이다', 'speaker': '캘빈 쿨리지'},
#  {'content': '평화를 원하거든 전쟁을 대비하라', 'speaker': '플라비우스 베게티우스 레나투스'},
# ...
#  {'content': '사물이 더 변할수록, 그것들은 더욱... 광적인 상태를 유지한다', 'speaker': '마이클 프라이'},
#  {'content': '수정을 용납하지 않는 계획은 나쁜 계획이다', 'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '나는 과거 속에 사는 편인데 내 생애 대부분이 거기 있기 때문이다', 'speaker': '허브 캐언'},
#  {'content': '인간은 너무 많은 지식을 갖고 있어서 통치하기 어렵다', 'speaker': '노자'},
#  {'content': '예술과 사랑을 하기에는 인생이 짧다', 'speaker': '윌리엄 서머셋 모옴'},
#  {'content': '자신을 믿지 못하는 자는 다른 누구도 진정으로 믿지 못한다', 'speaker': '장 레츠'},
#  {'content': '다른 개들이 푸들을 이상한 사이비 종교 신도라고 생각할지 궁금하다', 'speaker': '리타 러드너'},
#  {'content': '모든 여성의 몸은 있는 그대로 받아들여지길 요구한다', 'speaker': '글로리아 스타이넘'},
#  {'content': '나는 언제나 찬양 받기만을 원하는 신을 믿을 수 없다', 'speaker': '프레드리히 니체'},
#  {'content': '의사소통에 문제가 있는 사람은 그냥 입 닥쳤으면 좋겠다', 'speaker': '톰 레러'},
#  {'content': '초상화를 그릴 때마다 나는 친구를 하나씩 잃는다', 'speaker': '존 싱어 사전트'},
#  {'content': '자기 자식을 알면 현명한 아버지이다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '이 세상에서 가장 이해할 수 없는 말은 이 세상을 이해할 수 있다는 말이다',
#   'speaker': '알버트 아인슈타인'},
#  {'content': '부는 지혜로운 사람의 노예이자 바보의 주인이다', 'speaker': '세네카'},
#  {'content': '내 인생에서 한가지 후회는 내가 남이 아니라는 것이다', 'speaker': '우디 알렌'},
#  {'content': '영원히 살 것처럼 꿈꾸고 오늘 죽을 것처럼 살아라', 'speaker': '제임스 딘'},
#  {'content': '평화로울 때에는 조심스러움과 겸손함만큼 남자답게 만드는 것이 없다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '친구란 무엇인가? 두 개의 몸에 깃든 하나의 영혼이다', 'speaker': '아리스토텔레스'},
#  {'content': '무지한 자를 논쟁에서 누르기는 불가능하다', 'speaker': '윌리엄 매커두'},
#  {'content': '즐길 수 있을 때 충분히 즐기고, 참아야 할 때 꾹 참아라', 'speaker': '요한 볼프강 폰 괴테'},
#  {'content': '어느 국가든 그 기초는 젊은이들의 교육이다', 'speaker': '디오게네스 라에르티오스'},
#  {'content': '불의가 없다면 인간은 정의를 알지 못할 것이다', 'speaker': '헤라클레이토스'},
#  {'content': '인간은 자기 자식이 집으로 돌아오도록 허락하는 유일한 피조물이다', 'speaker': '빌 코스비'},
#  {'content': '교육이란 똑같은 생각을 찍어내는 국영 공장이다', 'speaker': '노먼 더글러스'},
#  {'content': '인생은 거짓된 상황의 끝없는 연속이다', 'speaker': '소온톤 와일더'},
#  {'content': '인생에 필요한 것은 무지와 확신 뿐이다. 그러면 성공은 확실하다', 'speaker': '마크 트웨인'},
#  {'content': '영원한 젊음의 비밀은 발육이 정지되는 것이다', 'speaker': '앨리스 루즈벨트 롱워스'},
#  {'content': '같은 것을 놓고 좋아하고 싫어하는 것. 그것이 바로 진정한 우정이다', 'speaker': '살루스트'},
#  {'content': '마치 멋진 노래를 부르는 작은 새가 된 것 같은 기분이야!', 'speaker': '제리 밴 아메론겐'},
#  {'content': '언젠가 적이 될 수도 있다는 듯 친구를 대하라', 'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '사랑은 눈으로 보지 않고 마음으로 보는 거지', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '인생은 하나의 치명적 통증이며 아주 전염성이 강한 통증이다', 'speaker': '올리버 웬델 홈스'},
#  {'content': '스스로를 소유하는 특권을 위한 대가는 아무리 비싸도 과하지 않다', 'speaker': '프레드리히 니체'},
#  {'content': '근거없이 지적인 원칙들에 습관이 드는 것을 우리는 신앙이라 부른다', 'speaker': '프레드리히 니체'},
#  {'content': '아이들은 부모를 사랑함으로써 출발하고 나이가 들면서 부모를 평가하며 때때로 부모를 용서하기도 한다',
#   'speaker': '오스카 와일드'},
#  {'content': "마약 중독자들과 컴퓨터 매니아들 둘 다 '사용자'라 부르는 이유는 뭔가?", 'speaker': '클리포드 스톨'},
#  {'content': '우리 육체는, 그 안에 사는 우리에게 결여된 지혜를 가지고 있다', 'speaker': '헨리 밀러'},
#  {'content': '서로를 용서하는 것이야말로 가장 아름다운 사랑의 모습이다', 'speaker': '존 셰필드'},
#  {'content': '인생이란 누구나 한 번쯤 시도해 볼 만한 것이다', 'speaker': '헨리 J. 틸만'},
#  {'content': '육아를 몇 사람이 분담하지 못할 이유는 없다', 'speaker': 'H. R. 셰퍼'},
#  {'content': '누가 경기를 시작했는지는 중요하지 않다. 누가 경기를 끝냈느냐가 중요하다', 'speaker': '존 우든'},
#  {'content': '가난으로 재능이 좌절된 사람은 출세하기 쉽지 않다', 'speaker': '유베날리스'},
#  {'content': '꺼지지 않을 불길로 타올라라', 'speaker': '루이사 시게아'},
#  {'content': '과도한 사랑은 인간에게 아무런 명예나 가치도 가져다주지 않는다', 'speaker': '에우리피데스'},
#  {'content': '만약 당신의 부모가 한 번도 아이를 가진 적이 없다면 당신도 그럴 가능성이 크다',
#   'speaker': '딕 카벳'},
#  {'content': '모든 것이 흑백이 아니라면, "대체 왜 아닌가?"라고 나는 묻는다', 'speaker': '존 웨인'},
#  {'content': '늑대들은 침묵하고 달만 울부짖는 밤이 있다', 'speaker': '조지 칼린'},
#  {'content': '정신적 자각의 첫 단계는 몸을 통해 성취해야 한다', 'speaker': '조지 시한'},
#  {'content': '할 수 있는 자는 행한다. 할 수 없는 자는 가르친다', 'speaker': '조지 버나드 쇼'},
#  {'content': '천재는 거대한 인내일 뿐이다', 'speaker': '뷔퐁'},
#  {'content': '인생은 지긋지긋한 일의 반복이다', 'speaker': '엘버트 허버드'},
#  {'content': '나는 외톨이가 되고 싶지는 않지만, 사람들이 나를 혼자 내버려뒀으면 좋겠다', 'speaker': '오드리 햅번'},
#  {'content': '성공은 종종 실패가 불가피하다는 것을 모르는 사람들에 의해 달성된다.', 'speaker': '코코) 샤넬'},
#  {'content': '차라리 다른 일을 하는 편이 낫다고 여기지 않는 한 그 어떠한 일도 진정한 일이 아니다',
#   'speaker': '제임스 M. 배리'},
#  {'content': '제 아무리 막강한 핵무기도 게릴라전을 막을 수는 없습니다', 'speaker': '존 F. 케네디'},
#  {'content': '영리한 사람은 거의 모든 것을 우습게 보지만, 분별있는 사람은 아무것도 우습게 보지 않는다',
#   'speaker': '요한 볼프강 폰 괴테'},
#  {'content': '의심으로 가득 찬 마음은 승리로의 여정에 집중할 수 없다', 'speaker': '아서 골든'},
#  {'content': '그것들은 여전히 귀를 간지르는 개살구같은 논쟁이기 때문이다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '자신의 부족한 점을 더 많이 부끄러워할 줄 아는 이는 더 존경 받을 가치가 있는 사람이다',
#   'speaker': '조지 버나드 쇼'},
#  {'content': '훌륭한 명성은 재물에 비할 바 아니다', 'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '행동 없는 말은 이상주의를 훼손한다', 'speaker': '허버트 후버'},
#  {'content': '지붕은 햇빛이 밝을 때 수리해야 합니다', 'speaker': '존 F. 케네디'},
#  {'content': '당신의 아이가 저녁을 살 때만 뭘 먹고 싶은지 물어봐라.(왕자처럼 키워서는 안된다.)',
#   'speaker': '프란 레보비츠'},
#  {'content': '지혜는 연륜이 아닌 능력으로 얻어진다', 'speaker': '플라우투스'},
#  {'content': '내가 본래 정직한 건 아니지만 가끔 우연히 정직할 때도 있다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '나는 때를 놓쳤고, 그래서 지금은 시간이 나를 낭비하고 있는 거지', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '어느 나라에서든 부자는 땅을 기어다니는 벌레다', 'speaker': 'G. K. 체스터튼'},
#  {'content': 'PC가 등장했을 때 사람들은 그것이 중요하다는 것을 알았다', 'speaker': '빌 게이츠'},
#  {'content': '내일은 우리가 어제로부터 무엇인가 배웠기를 바란다', 'speaker': '존 웨인'},
#  {'content': '휴대할 수 있는 것만 소유하고, 언어, 국가, 사람들을 알아라. 기억을 여행 가방 삼아라',
#   'speaker': '알렉산드르 솔제니친'},
#  {'content': '지금이 제일 비참하다고 할 수 있는 동안은 아직 제일 비참한 게 아니다',
#   'speaker': '윌리엄 셰익스피어'},
#  {'content': '출생과 죽음은 피할 수 없으므로 그 사이를 즐겨라', 'speaker': '조지 산타야나'},
#  {'content': '존재의 가장 중요한 이유, 세상을 사는 이유는 발견이다', 'speaker': '제임스 딘'},
#  {'content': '남자들이 어린 아이 같다는 것을 안다면, 모든 것을 알고 있는 것이다!', 'speaker': '코코) 샤넬'},
#  {'content': '우리가 행하는 모든 예술은 견습에 불과하다. 위대한 예술이란 바로 우리의 인생이다',
#   'speaker': 'M. C. 리처즈'},
#  {'content': '아첨은 모두 옳다. 고지식하게 그대로 받아들이지 않는다면', 'speaker': '아들라이 E. 스티븐슨'},
#  {'content': '친구를 용서하는 것보다 적을 용서하는 것이 더 쉽다', 'speaker': '윌리엄 블레이크'},
#  {'content': '인간은 오직 사고(思考)의 산물일 뿐이다. 생각하는 대로 되는 법', 'speaker': '마하트마 간디'},
#  {'content': '인생에서 가장 의미없이 보낸 날은 웃지 않고 보낸 날이다', 'speaker': 'E. E. 커밍스'},
#  {'content': '비즈니스계에서는 백미러가 앞 유리보다 항상 더 선명하다', 'speaker': '워런 버핏'},
#  {'content': '무엇을 비웃는가보다 한 사람의 성격을 더 잘 보여주는 것은 없다', 'speaker': '요한 볼프강 폰 괴테'},
#  {'content': '불운을 극복하는 유일한 것은 열심히 노력하는 것이다', 'speaker': '해리 골든'},
#  {'content': '우리는 그 어떤 것에 대해서 1억 분의 1도 모른다', 'speaker': '토마스 A. 에디슨'},
#  {'content': '음식에 대한 사랑보다 더 진실된 사랑은 없다', 'speaker': '조지 버나드 쇼'},
#  {'content': '무지를 아는 것이 곧 앎의 시작이다', 'speaker': '소크라테스'},
#  {'content': '네 작품이 누가 봐도 훌륭하면, 침묵하라', 'speaker': '헨리 J. 카이저'},
#  {'content': "너는 네가 길들인 것에 대해 영원히 책임져야 하는거야.('어린 왕자')", 'speaker': '생텍쥐페리'},
#  {'content': '통계자료는 술 취한 사람 옆의 가로등과 같아서 빛을 내기보다는 지지하기 위해 쓰인다',
#   'speaker': '윈스턴 처칠'},
#  {'content': '수상한 남자의 차를 얻어 타지 말고, 모든 남자는 수상하다는 사실을 항상 기억하라',
#   'speaker': '로빈 모건'},
#  {'content': '완전한 진실만을 말하는 방법은 두 가지뿐이다. 익명으로 하거나, 유언으로 하거나',
#   'speaker': '토머스 소웰'},
#  {'content': '가장 진정한 의미에서 자유는 수여될 수 없으며 쟁취해야 한다', 'speaker': '프랭클린 D. 루스벨트'},
#  {'content': '계획 없는 목표는 한낱 꿈에 불과하다', 'speaker': '생텍쥐페리'},
#  {'content': '음악이 없다면 인생은 잘못된 것이다', 'speaker': '프레드리히 니체'},
#  {'content': '실제의 세상은 상상의 세상보다 훨씬 작다', 'speaker': '프레드리히 니체'},
#  {'content': '너의 성공이나, 친구의 성공만큼 확실하게 친구에 대한 너의 생각을 바꿔주는 것은 없다',
#   'speaker': '프랭클린 P. 존스'},
#  {'content': '건강은 이웃과 같은 질병을 앓는 것으로 이루어진다', 'speaker': '쿠엔틴 크리스프'},
#  {'content': '어리석은 자는 용서하지도 잊지도 않는다. 순진한 자는 용서하고 잊는다. 현명한 자는 용서하나 잊지는 않는다',
#   'speaker': '토머스 사즈'},
#  {'content': '나는 노아의 법칙을 위반했다. 비를 예측하는 것은 중요하지 않지만, 방주를 만드는 것은 중요하다',
#   'speaker': '워런 버핏'},
#  {'content': '상상력은 현실과의 전쟁에서 쓸 수 있는 무기다', 'speaker': '쥘 드 고티에'},
#  {'content': '불어라 불어라 겨울바람아. 너는 배은망덕한 사람만큼이나 무정하구나', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '성공적인 결혼은 늘 똑같은 사람과 여러 번 사랑에 빠지는 것을 필요로 한다',
#   'speaker': '미뇽 머클로플린'},
#  {'content': '신성한 것이 있다면 바로 인간의 몸이 신성하다', 'speaker': '월트 위트먼'},
#  {'content': '우리의 몸은 정원이요, 우리의 의지는 정원사다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '텍사스에 산다면 눈(snow)을 볼 때마다 마법처럼 느껴질 것이다', 'speaker': '파멜라 라이번'},
#  {'content': '나는 언제나 기혼 상태였기 때문에 성관계에 대해선 아무것도 모른다', 'speaker': '자자 가보'},
#  {'content': '만약 로큰롤이 불법이라면, 날 감방에 쳐 넣어요', 'speaker': '커트 코베인'},
#  {'content': '스스로를 신뢰하는 순간 어떻게 살아야 할지 깨닫게 된다', 'speaker': '요한 볼프강 폰 괴테'},
#  {'content': '경험을 현명하게 사용한다면, 어떤 일도 시간 낭비는 아니다', 'speaker': '오귀스트 르네 로댕'},
#  {'content': '진정한 성공은 평생의 일을 자신이 좋아하는 일에서 찾는 것이다', 'speaker': '데이비드 매컬로'},
#  {'content': '오, 그대여, 당신의 몸을 맞아들이고 몸이 당신을 편안하게 묶게 하라', 'speaker': '앤 섹스턴'},
#  {'content': '내 자신의 일은 항상 지겨워 죽겠다. 남의 일이 더 좋다', 'speaker': '오스카 와일드'},
#  {'content': '운명의 기복은 친구의 신뢰를 시험한다', 'speaker': '키케로'},
#  {'content': '인생이란 진지하게 이야기하기에는 너무나 중요한 것이다', 'speaker': '오스카 와일드'},
#  {'content': '축제에서 처신하듯 인생에서 처신해야 함을 명심하라', 'speaker': '에픽테토스'},
#  {'content': '사람의 정신은 한 번 새로운 생각으로 늘어나게 되면 다시는 원래의 수준으로 돌아갈 수 없다',
#   'speaker': '올리버 웬델 홈스'},
#  {'content': '발견은 준비된 사람이 맞닥뜨린 우연이다', 'speaker': '알버트 센트 디외르디'},
#  {'content': '적응성은 모방이 아니다. 그것은 저항과 동화의 힘을 뜻한다', 'speaker': '마하트마 간디'},
#  {'content': '천재는 지구가 절대로 길들일 수 없는 전기 같은 힘을 가졌다', 'speaker': '리디아 M. 차일드'},
#  {'content': '행복은 여정이지, 목적지가 아니라는 점을 기억하라', 'speaker': '로이 M. 굿맨'},
#  {'content': '내가 논쟁을 싫어 하는 이유는 항상 토론을 방해하기 때문이다', 'speaker': 'G. K. 체스터튼'},
#  {'content': '한갖 맹세보다는 고매한 인격을 더 믿어라', 'speaker': '솔론'},
#  {'content': '나는 단 한번도 이성적인 사고를 통해 발견한 적이 없다', 'speaker': '알버트 아인슈타인'},
#  {'content': '진리을 구하는 이들을 믿어라. 진리를 찾아내는 이들을 의심하라', 'speaker': '앙드레 지드'},
#  {'content': '우리는 나이가 들면서 변하는 게 아니다. 보다 자기다워지는 것이다', 'speaker': '린 홀'},
#  {'content': '용기와 인격을 갖춘 이들은 항상 다른 사람들에게 악의적으로 비춰진다', 'speaker': '헤르만 헤세'},
#  {'content': '반복은 예술의 죽음이다', 'speaker': '로빈 그린'},
#  {'content': '성공이란 중요한 생일이 다가왔는데 당신은 전과 똑같다는 사실을 발견하는 것과 같다',
#   'speaker': '오드리 햅번'},
#  {'content': '가장 심오한 발언은 종종 침묵 속에 나오는 경우가 많다', 'speaker': '린 존스턴'},
#  {'content': '정신병원을 태평하게 산책해보면 믿음이 아무것도 입증하지 못함을 알 수 있다',
#   'speaker': '프레드리히 니체'},
#  {'content': '서점만큼 인간의 심성이 그토록 약해지는 곳이 어디 있는가?', 'speaker': '헨리 워드 비처'},
#  {'content': '정직은 그 값을 한다. 하지만 어떤 사람들에게는 충분한 값어치를 못하는 것 같다',
#   'speaker': '킨 허바드'},
#  {'content': '사랑은 끝없는 용서의 행위이며, 습관으로 굳어지는 상냥한 표정이다', 'speaker': '피터 유스티노프'},
#  {'content': '왜 굳이 의미를 찾으려 하는가? 인생은 욕망이지, 의미가 아니다', 'speaker': '찰리 채플린'},
#  {'content': '유머는 단연코 두뇌의 가장 중요한 활동이다', 'speaker': '에드워드 드 보노'},
#  {'content': '질투심 많은 사람은 이웃 사람들이 살이 찔 때 마르게 된다', 'speaker': '호라티우스'},
#  {'content': '미래를 좌지우지하겠다는 욕망을 버리면 더 행복해질 수 있다', 'speaker': '니콜 키드먼'},
#  {'content': '군자는 마음이 평안하고 차분하나, 소인은 항상 근심하고 걱정한다. (君子坦荡荡 人长戚戚 / 군자탄탕탕 소인장척척)',
#   'speaker': '공자'},
#  {'content': '남의 말을 따라 하려면 교육이 필요하다. 그 말에 도전하려면 두뇌가 필요하다',
#   'speaker': '메리 페티본 풀'},
#  {'content': '행복한 가정은 모두 엇비슷하고, 불행한 가정은 제각각의 이유로 불행하다', 'speaker': '레프 톨스토이'},
#  {'content': '시련이 없다는 것은 축복 받은 적이 없다는 것이다', 'speaker': '에드거 앨런 포'},
#  {'content': '인생은 끔찍하거나 비참하거나 둘 중 하나다', 'speaker': '우디 알렌'},
#  {'content': '열정으로부터 견해가 생기고, 정신적 태만이 이를 신념으로 굳어지게 한다. (한번 생긴 견해를 비판하지 않아서 굳어진 신념은 독선이 되기 쉽다.)',
#   'speaker': '프레드리히 니체'},
#  {'content': '돈이 수중에 들어오기 전까진 절대로 쓰지 마라', 'speaker': '토마스 제퍼슨'},
#  {'content': '미래의 제국은 마음의 제국이다', 'speaker': '윈스턴 처칠'},
#  {'content': '아버지는 나에게 일을 하라고 가르치셨지만, 그 일을 사랑하라고 가르치지는 않았다',
#   'speaker': '에이브러햄 링컨'},
#  {'content': '전쟁은 평화의 문제로부터의 비겁한 도망이다', 'speaker': '토마스 만'},
#  {'content': '절대 결혼 생활에 고통보다 기쁨이 더 많다고 하지 말라', 'speaker': '에우리피데스'},
#  {'content': '많은 긍정적 사고를 가진 기업이 부정적 사고를 가진 기업을 인수해 부자가 됐다',
#   'speaker': '로버트 앨런'},
#  {'content': '몸은 가꾸고 단련하며 자랑하며, 세월이 흐르면 믿고 의지하게 된다', 'speaker': '마사 그레이엄'},
#  {'content': '가장 용감한 행동은 자신만을 생각하는 것이다. 큰 소리로.', 'speaker': '코코) 샤넬'},
#  {'content': '죄를 짓고 잘되는 사람도 있고, 덕을 베풀고 망하는 사람도 있다', 'speaker': '윌리엄 셰익스피어'},
#  {'content': '위대한 성취를 하려면 행동하는 것뿐만 아니라, 꿈꾸는 것도 반드시 필요하다',
#   'speaker': '아나톨 프랑스'},
#  {'content': '순간을 사랑하라. 그러면 그 순간의 에너지가 모든 경계를 넘어 퍼져나갈 것이다',
#   'speaker': '코리타 켄트'},
#  {'content': '미래를 예측하는 최선의 방법은 미래를 창조하는 것이다', 'speaker': '알랜 케이'},
#  {'content': '과학은 정리된 지식이다. 지혜는 정리된 인생이다', 'speaker': '임마누엘 칸트'},
#  {'content': '풍요 속에서는 친구들이 나를 알게 되고, 역경 속에서는 내가 친구를 알게 된다',
#   'speaker': '존 철튼 콜린스'},
#  {'content': '나는 오늘 아침 기념비적인 생각을 떠올렸다. 하지만 그걸 좋아하지는 않았다',
#   'speaker': '사무엘 골드윈'},
#  {'content': '논쟁할 때 그 사안을 이해할 필요는 없다', 'speaker': '피에르 보마르셰'},
#  {'content': '자신이 될 수 있는 존재가 되길 희망하는 것이 삶의 목적이다', 'speaker': '신시아 오지크'},
#  {'content': '가장 자극적인 매력은 결코 만나지 않는 양극 간에 존재한다', 'speaker': '앤디 워홀'},
#  {'content': '고마워할 줄 모르는 아이를 갖는다는 것은 뱀의 이빨보다 얼마나 더 날카로운지!',
#   'speaker': '윌리엄 셰익스피어'},
#  {'content': '인류는 불평하고 싶은 욕망을 충족하기 위해 언어를 발명했다', 'speaker': '릴리 톰린'},
#  {'content': '화가 난 사람이 당신에게 한 말을 절대 잊지 말라', 'speaker': '헨리 워드 비처'},
#  {'content': '겸손해지면 젊은 청년이 된다', 'speaker': '플라우투스'},
#  {'content': '시의적절한 침묵은 말보다 설득력 있다', 'speaker': '마틴 파쿠아 터퍼'},
#  {'content': '현재를 사는 법을 배우는 것은 기쁨의 행로의 일부다', 'speaker': '사라 밴 브레스낙'},
#  {'content': '일반 대중이란 개념은 사실 산업 혁명이 고안해낸 것이다', 'speaker': '데이빗 크로넨버그'},
#  {'content': '모든 문제에는 인내가 최고의 해법이다', 'speaker': '플라우투스'},
#  {'content': '무언가를 열렬히 원한다면 그것을 얻기 위해 전부를 걸만큼의 배짱을 가져라',
#   'speaker': '브렌단 프랜시스'},
#  {'content': '분산투자는 자신이 무엇을 하고 있는지 잘 모르는 투자가에게만 알맞는 투자방법이다',
#   'speaker': '워런 버핏'},
#  {'content': '모든 소리 중에 음악이 가장 덜 불쾌하다', 'speaker': '사무엘 존슨'},
#  {'content': '교육은 배운 것이 잊혀졌을 때 살아 남는 것이다', 'speaker': 'B. F. 스키너'},
#  {'content': '천재란 자신에게 주어진 일을 하는 재능 있는 사람일 뿐이다', 'speaker': '토마스 A. 에디슨'},
#  {'content': '삶은 소유가 아닌 창조를 통해 드러난다', 'speaker': '비다 D. 스커더'},
#  {'content': '스포츠는 인격을 함양시켜주지 않는다. 단지 그것을 드러낼 뿐이다', 'speaker': '헤이우드 브룬'},
#  {'content': '전국에 경기장을 짓네요. 이 곳과 몬트리올만 빼고 말이죠', 'speaker': '시드 비셔스'},
#  {'content': '내가 혐오하는 것들은 단순하다. 우둔, 억압, 범죄, 잔인함, 그리고 부드러운 음악이다',
#   'speaker': '블라디미르 나보코프'},
#  {'content': '미래는 현재와 무척 닮았다. 단지 더 길뿐이다', 'speaker': '댄 퀸스베리'},
#  {'content': '사랑을 하는 사람과 사랑을 받는 사람은 항상 따로 있어', 'speaker': '서머셋 모옴'},
#  {'content': '무엇을 먹는지 말하라. 그러면 당신이 어떤 사람인지 말해 주겠다', 'speaker': '앙텔므 브리야 샤바랭'},
#  {'content': '행동의 가치는 그 행동을 끝까지 이루는 데 있다', 'speaker': '칭기즈칸'},
#  {'content': '봄에 생기는 약간의 광기는 심지어 왕에게도 유익하다', 'speaker': '에밀리 디킨스'},
#  {'content': '봄이란 설사 눈녹은 진창물에 발이 빠졌다 하더라도 휘파람을 불고 싶은 때이다', 'speaker': '더그 라슨'},
#  {'content': '나는 내 인격의 완전한 표현을 위해 자유를 원한다', 'speaker': '마하트마 간디'},
#  {'content': '민주주의에 대한 최고의 반론은 평범한 유권자와의 5분 대화이다', 'speaker': '윈스턴 처칠'},
#  {'content': '음식은 균형 잡힌 식단의 중요한 부분을 차지한다', 'speaker': '프란 레보비츠'},
#  {'content': '삶은 사람의 용기에 비례하여 넓어지거나 줄어든다', 'speaker': '아나이스 닌'},
#  {'content': '낙관론이 가장 많이 꽃피는 곳은 정신병원이다', 'speaker': '해브록 엘리스'},
#  {'content': '순교는 능력 없이 유명해질 수 있는 유일한 방법이다', 'speaker': '조지 버나드 쇼'},
#  {'content': '삶은 즐겁다. 죽음은 평화롭다. 골칫거리는 바로 그 중간과정이다', 'speaker': '아이작 아시모프'},
#  {'content': '중요한 일에 집중할 수 있는 능력이 바로 지능의 가장 결정적인 특징이다',
#   'speaker': '로버트 J. 쉴러'},
#  {'content': '젊음은 희망을 빨리 갖기 때문에 그만큼 쉽게 현혹된다', 'speaker': '아리스토텔레스'},
#  {'content': '나의 개인적인 취미는 독서, 음악감상, 침묵이다', 'speaker': '이디스 시트웰'},
#  {'content': '희극은 그저 재미있게 진지한 것이다', 'speaker': '피터 유스티노프'},
#  {'content': '꿈을 기록하는 것이 나의 목표였던 적은 없다, 꿈을 실현하는 것이 나의 목표이다',
#   'speaker': '만 레이'},
#  {'content': '당신이 진정으로 믿는 일은 반드시 이루어진다. 그 믿음이 그것을 실현시킨다',
#   'speaker': '프랭크 로이드 라이트'},
#  {'content': '지식은 행동을 통해 얻어야 한다. 재판을 제외하면 상상 속의 시험이 아닌 시험은 없다',
#   'speaker': '소포클레스'},
#  {'content': '자존심은 강력한 마약이지만, 자가면역 체계에는 별 도움이 되지 않는다', 'speaker': '스튜어트 스티븐스'},
#  {'content': '너무 엄격한 규칙에 따라 건강을 지키는 것은 심각한 병이다', 'speaker': '프랑수아 드 라 로슈푸코'},
#  {'content': '신경증 환자는 공중누각을 만들고 정신병자는 거기에 산다. 내 어머니는 그곳을 깨끗하게 한다',
#   'speaker': '리타 러드너'},
#  {'content': '솔직한 (의견) 차이는 대개 진보를 위한 건강한 신호다', 'speaker': '마하트마 간디'},
#  {'content': '감사는 정중함의 가장 아름다운 표현이다', 'speaker': '자크 마리탱'},
#  {'content': '젊음은 매우 새로운 것이다. 20년 전에는 아무도 이것을 언급하지 않았다.', 'speaker': '코코) 샤넬'},
#  {'content': '비폭력은 인류가 활용할 수 있는 가장 강력한 힘이다', 'speaker': '마하트마 간디'},
#  {'content': '내가 한 말에 대해서는 종종 후회하지만 침묵한 것을 후회한 적은 없다',
#   'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '이 인생에서는 마지막에 웃는 자가 가장 오래 웃는 자다', 'speaker': '존 메이스필드'},
#  {'content': '아첨꾼은 나보다 열등하거나 그런 척 하는 친구이다', 'speaker': '아리스토텔레스'},
#  {'content': '기회 없는 능력은 쓸모가 없다', 'speaker': '나폴레옹 보나파르트'},
#  {'content': '죽음을 무시하기 보다는 인정하라. 죽음 역시 자연의 섭리 중 하나이므로',
#   'speaker': '마르쿠스 아우렐리우스 안토니우스'},
#  {'content': '우리는 아는 것이 거의 없을 때만 정확히 안다. 앎과 함께 의심도 늘어간다',
#   'speaker': '요한 볼프강 폰 괴테'},
#  {'content': '모든 사람은 죽음 앞에 평등하다', 'speaker': '퍼블릴리어스 사이러스'},
#  {'content': '충성과 신의를 첫 번째 원칙으로 지켜라. (主忠信 / 주충신)', 'speaker': '공자'},
#  {'content': '교육은 노후로 가는 여행을 위한 최상의 양식이다', 'speaker': '아리스토텔레스'},
#  {'content': '나는 조용하고 까다롭고 영원한 동반자인 몸과 함께 산다', 'speaker': '외젠 들라크루아'},
#  {'content': '다른 사람의 생각에 인생을 맞춰가는 것은 노예나 다름 없다', 'speaker': '라와나 블랙웰'},
#  {'content': '위대한 미모와 위대한 미덕이 함께 있는 경우는 드물다', 'speaker': '페트라르카'},
#  {'content': '정의란 모든 이에게 합당한 몫을 나누어 주려는 지속적이고 영구적인 의지이다',
#   'speaker': '도미투스 우르피안'},
#  {'content': '당신이 오늘 베푼 선행은 내일이면 사람들에게 잊혀질 것이다. 그래도 선행을 베풀어라',
#   'speaker': '마더 테레사'},
#  {'content': '나에게 창의성은 안 먹고는 살 수 없는 약과 같다', 'speaker': '세실 B. 드밀'},
#  {'content': '자신에 관해 많은 말을 함으로써 자신을 감출 수도 있다', 'speaker': '프레드리히 니체'}]

# %%
from elasticsearch.helpers import bulk
import hashlib

before_indexing(es) # set indexing mode

actions = []
for row in docs: 
    d = FamousSaying(speaker=row['speaker'], content=row['content'])
    actions.append(d.to_dict(include_meta=True))

success, _ = bulk(es, actions, index=FamousSaying.index, raise_on_error=True)

after_indexing(es) # unset indexing mode

print('success docs:', success)
# Out:
# recreate index... 'famous_saying_v2'
# recreate index OK
# success docs: 1000

# %% [markdown]
# # Wait for a moment

# %% [markdown]
# # Searching (Elasticsearch HQ)
# - total docs = 1000?
# - (공백)
# - speaker:"사무엘 존슨"
# - content:사람은
# - (Sort by Descending)

# %% [markdown]
# # Searching (curl)
# https://www.elastic.co/guide/en/elasticsearch/reference/current/search-search.html

# %% [raw]
# curl -XGET 'http://localhost:9200/famous_saying_v1/famous_saying/_search?pretty=true&q=speaker:사무엘%20존슨'

# %% [markdown]
# # Searching (python)

# %%
import logging
class Searcher(object):
    def __init__(self, index=FamousSaying.index, doc_type=FamousSaying.doc_type):
        logging.getLogger("urllib3").setLevel(logging.CRITICAL)
        logging.getLogger("requests").setLevel(logging.CRITICAL)
        logging.getLogger('elasticsearch').setLevel(logging.CRITICAL)
        logging.getLogger('elasticsearch.trace').setLevel(logging.CRITICAL)

        self.es = Elasticsearch(hosts='localhost', timeout=300)
        self.index = index
        self.doc_type = doc_type
        
    def escape(self, keyword):     # escaping characters
        keyword = keyword.replace('_', ' ')
        for c in ['.', '%', '+', '-', '=', '&&', '||', '>', '<', '!', '(', ')', '{', '}', '[', ']', '^', '"', '~', '*',
                  '?', ':', '/']:  # '\\',ççç
            keyword = keyword.replace(c, r'\%s' % c)
        return keyword
    
    def search(self, q, field='content'):
        q = '%s:%s' % (field, q) # make query
        r = self.es.search(index=self.index, doc_type=self.doc_type, q=q) # q=Query String Query
        return r
    
    def search_all(self, q, field='content'):
        q = '%s:%s' % (field, q) # make query
        hits = []
        r = self.es.search(index=self.index, doc_type=self.doc_type, q=q) # q=Query String Query
        hits.extend(r['hits']['hits'])
        
        while r['hits']['total'] > len(hits): # need more hits
            _r = self.es.search(index=self.index, doc_type=self.doc_type, q=q, from_=len(hits)) # q=Query String Query
            hits.extend(_r['hits']['hits'])
            r['took'] += _r['took'] # sum elapsed time.
        
        r['hits']['hits']=hits
        return r
    
searcher = Searcher(index=FamousSaying.index, doc_type=FamousSaying.doc_type)

# %%
# search not_analyzed field. (term==field)
searcher.search('사무엘 존슨', field='speaker')
# Out:
# {'_shards': {'failed': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '1a5a8b698307135eb76b3dea101f14d7',
#     '_index': 'famous_saying_v2',
#     '_score': 0.7063996,
#     '_source': {'content': '희망은 어떤 상황에서도 필요하다',
#      'content_length': 4,
#      'speaker': '사무엘 존슨'},
#     '_type': 'famous_saying'},
#    {'_id': '31f172fa3e73e006261a952fc65bc8a9',
#     '_index': 'famous_saying_v2',
#     '_score': 0.57716525,
#     '_source': {'content': '모든 소리 중에 음악이 가장 덜 불쾌하다',
#      'content_length': 7,
#      'speaker': '사무엘 존슨'},
#     '_type': 'famous_saying'},
#    {'_id': '083b90b2254ae7db8f68c52a5a07c880',
#     '_index': 'famous_saying_v2',
#     '_score': 0.46265098,
#     '_source': {'content': '좋은 일을 많이 해내려고 기다리는 사람은 하나의 좋은 일도 해낼 수가 없다.',
#      'content_length': 12,
#      'speaker': '사무엘 존슨'},
#     '_type': 'famous_saying'}],
#   'max_score': 0.7063996,
#   'total': 3},
#  'timed_out': False,
#  'took': 2}

# %%
# search not_analyzed field. (term==field)
searcher.search('사무엘', field='speaker')['hits']
# Out:
# {'hits': [], 'max_score': None, 'total': 0}

# %%
# search not_analyzed field. (term==field)
searcher.search('존슨', field='speaker')['hits']
# Out:
# {'hits': [], 'max_score': None, 'total': 0}

# %%
# search analyzed field. (term!=field)
searcher.search('사람은', field='content')['hits']
# Out:
# {'hits': [{'_id': 'cfa73a1dc3a7cfb090e4a61993e64aee',
#    '_index': 'famous_saying_v2',
#    '_score': 1.9953598,
#    '_source': {'content': '위대한 사람은 모두가 겸손하다.',
#     'content_length': 4,
#     'speaker': '레싱'},
#    '_type': 'famous_saying'},
#   {'_id': '449724eee6d39076cf7f956a6f830924',
#    '_index': 'famous_saying_v2',
#    '_score': 1.825614,
#    '_source': {'content': '모든 사람은 죽음 앞에 평등하다',
#     'content_length': 5,
#     'speaker': '퍼블릴리어스 사이러스'},
#    '_type': 'famous_saying'},
#   {'_id': 'e0b951aeca496355bfcd8089b9a68b53',
#    '_index': 'famous_saying_v2',
#    '_score': 1.7325459,
#    '_source': {'content': '사람은 스스로 믿는 대로 된다',
#     'content_length': 5,
#     'speaker': '안톤 체홉'},
#    '_type': 'famous_saying'},
#   {'_id': 'ff265067d1be4c307963651ce45b2c3c',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6540035,
#    '_source': {'content': '무관심 때문에 사람은 실제로 죽기전에 죽어버린다.',
#     'content_length': 6,
#     'speaker': '위젤'},
#    '_type': 'famous_saying'},
#   {'_id': 'a5ec40eaebc51f336cb2584b2c9d83bb',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6540035,
#    '_source': {'content': '시간을 이용할줄 아는 사람은 하루를 사흘로 통용한다.',
#     'content_length': 7,
#     'speaker': '영국속담'},
#    '_type': 'famous_saying'},
#   {'_id': '502e9a82ad744d9e777660e8633b2e21',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6540035,
#    '_source': {'content': '마음이 어진 사람은 조그마한 집에 살아도 행복하다.',
#     'content_length': 7,
#     'speaker': '홍자성'},
#    '_type': 'famous_saying'},
#   {'_id': '532bc607c4a701f2616216b9287d38aa',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6540035,
#    '_source': {'content': '키스하는 두 사람은 항상 물고기처럼 보인다',
#     'content_length': 6,
#     'speaker': '앤디 워홀'},
#    '_type': 'famous_saying'},
#   {'_id': 'fbbd0a65f29a8f43baa4e6947a35a19b',
#    '_index': 'famous_saying_v2',
#    '_score': 1.564812,
#    '_source': {'content': '생각이 깊지 못한 사람은 항상 입을 놀린다.',
#     'content_length': 7,
#     'speaker': '호머'},
#    '_type': 'famous_saying'},
#   {'_id': 'cf4b9e7e71a428659d7e664e5e1912c9',
#    '_index': 'famous_saying_v2',
#    '_score': 1.564812,
#    '_source': {'content': '남의 말을 열심히 들어주다가 해고당한 사람은 없다',
#     'content_length': 7,
#     'speaker': '캘빈 쿨리지'},
#    '_type': 'famous_saying'},
#   {'_id': 'cfabc55a4aee6c24aa4eb7a52f6d7e3e',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4965198,
#    '_source': {'content': '산을 옮기는 사람은 작은 돌맹이부터 옮긴다.',
#     'content_length': 6,
#     'speaker': '중국 속담'},
#    '_type': 'famous_saying'}],
#  'max_score': 1.9953598,
#  'total': 41}

# %%
searcher.search('사람은', field='content')['hits']['total']
# Out:
# 41

# %%
print(len(searcher.search('사람은', field='content')['hits']['hits'])) # total != searched docs
print(len(searcher.search_all('사람은', field='content')['hits']['hits'])) # total == searched docs
# Out:
# 10
# 41

# %%
# search analyzed field.
searcher.search('좋은 일을 많이 해내려고 기다리는 사람은 하나의 좋은 일도 해낼 수가 없다.', field='content')['hits']
# Out:
# {'hits': [{'_id': '083b90b2254ae7db8f68c52a5a07c880',
#    '_index': 'famous_saying_v2',
#    '_score': 4.5204167,
#    '_source': {'content': '좋은 일을 많이 해내려고 기다리는 사람은 하나의 좋은 일도 해낼 수가 없다.',
#     'content_length': 12,
#     'speaker': '사무엘 존슨'},
#    '_type': 'famous_saying'},
#   {'_id': '3eb1146a1bdc115e3de490cd80149c2e',
#    '_index': 'famous_saying_v2',
#    '_score': 0.36934742,
#    '_source': {'content': '핑계를 잘 대는 사람은 거의 좋은 일을 하나도 해내지 못한다.',
#     'content_length': 10,
#     'speaker': '벤자민 프랭클린'},
#    '_type': 'famous_saying'},
#   {'_id': '7ad17268626b0e358b80ad49ccdfeed7',
#    '_index': 'famous_saying_v2',
#    '_score': 0.2435174,
#    '_source': {'content': '좋은 나무는 좋은 열매를 맺는다.',
#     'content_length': 5,
#     'speaker': '랭런드'},
#    '_type': 'famous_saying'},
#   {'_id': 'fac556cf38ac4875ae3461ee8d67eba4',
#    '_index': 'famous_saying_v2',
#    '_score': 0.22338933,
#    '_source': {'content': '좋은 전쟁 또는 나쁜 평화는 없다.',
#     'content_length': 6,
#     'speaker': '프랭클린'},
#    '_type': 'famous_saying'},
#   {'_id': '6356947910e6fa7ab458b71649adb5cd',
#    '_index': 'famous_saying_v2',
#    '_score': 0.22338933,
#    '_source': {'content': '필요하면 결코 좋은 흥정을 할 수 없다',
#     'content_length': 7,
#     'speaker': '벤자민 프랭클린'},
#    '_type': 'famous_saying'},
#   {'_id': 'bbb82f49a0c88e982a350dc62b56122e',
#    '_index': 'famous_saying_v2',
#    '_score': 0.20786695,
#    '_source': {'content': '어느 사회에서나 유아들에게 우유를 먹이는 것보다 더 좋은 투자는 없다.',
#     'content_length': 10,
#     'speaker': '처칠'},
#    '_type': 'famous_saying'},
#   {'_id': '8cdcff13c81113f5da6d9e8a5a9a8e7d',
#    '_index': 'famous_saying_v2',
#    '_score': 0.20786695,
#    '_source': {'content': '좋은 디자인이 고장난 비즈니스 모델을 고칠 수는 없다',
#     'content_length': 8,
#     'speaker': '제프리 빈'},
#    '_type': 'famous_saying'},
#   {'_id': 'a08901497799640950ca75d6814fbff9',
#    '_index': 'famous_saying_v2',
#    '_score': 0.20377639,
#    '_source': {'content': '지식과 목재는 세파에 시달리지 아니하면 많이 애용될 수가 없다.',
#     'content_length': 9,
#     'speaker': '올리버 웬델 홈즈'},
#    '_type': 'famous_saying'},
#   {'_id': '7941d78d36c436ddff220ade702f86f7',
#    '_index': 'famous_saying_v2',
#    '_score': 0.19809023,
#    '_source': {'content': '성실하지 못한 사람은 위대한 것들을 생산할 수가 없다.',
#     'content_length': 8,
#     'speaker': '제임스 럿셀 로우웰'},
#    '_type': 'famous_saying'},
#   {'_id': 'fcef5a62ffdc3626564ca3f0800a74f2',
#    '_index': 'famous_saying_v2',
#    '_score': 0.1854384,
#    '_source': {'content': '좋은 친구는 건강에도 좋다.',
#     'content_length': 4,
#     'speaker': '시라손'},
#    '_type': 'famous_saying'}],
#  'max_score': 4.5204167,
#  'total': 154}

# %% [markdown]
# # Query String Query
# https://www.elastic.co/guide/en/elasticsearch/reference/current/query-dsl-query-string-query.html

# %%
r = searcher.search_all('"수 있는"', field='content')['hits']
r['total'], r['hits'][-5:]
# Out:
# (25,
#  [{'_id': 'd473bf9affcdf123bc3e2ccb70e12ad3',
#    '_index': 'famous_saying_v2',
#    '_score': 2.0365524,
#    '_source': {'content': '인생에 대해 내가 말할 수 있는 전부는, 오 하나님, 즐기라는 거다!',
#     'content_length': 11,
#     'speaker': '밥 뉴하트'},
#    '_type': 'famous_saying'},
#   {'_id': 'a9fada90360b1741668e3c5a96cb5df2',
#    '_index': 'famous_saying_v2',
#    '_score': 1.9323975,
#    '_source': {'content': '가치있는 적이 될 수 있는 자는 화해하면 더 가치있는 친구가 될 것이다.',
#     'content_length': 12,
#     'speaker': '펠담'},
#    '_type': 'famous_saying'},
#   {'_id': 'de81075004fd35b654f147ab498d14cc',
#    '_index': 'famous_saying_v2',
#    '_score': 1.8747534,
#    '_source': {'content': '중요한 일에 집중할 수 있는 능력이 바로 지능의 가장 결정적인 특징이다',
#     'content_length': 11,
#     'speaker': '로버트 J. 쉴러'},
#    '_type': 'famous_saying'},
#   {'_id': 'a1468a5d4b79726e4bff5e168f864fa7',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6903859,
#    '_source': {'content': '휴대할 수 있는 것만 소유하고, 언어, 국가, 사람들을 알아라. 기억을 여행 가방 삼아라',
#     'content_length': 13,
#     'speaker': '알렉산드르 솔제니친'},
#    '_type': 'famous_saying'},
#   {'_id': 'feb994ed01d1600201ce9218db5ad467',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6903859,
#    '_source': {'content': '지금이 제일 비참하다고 할 수 있는 동안은 아직 제일 비참한 게 아니다',
#     'content_length': 12,
#     'speaker': '윌리엄 셰익스피어'},
#    '_type': 'famous_saying'}])

# %%
r = searcher.search_all('"수" AND "있는"', field='content')['hits']
r['total'], r['hits'][-5:]
# Out:
# (26,
#  [{'_id': 'b530b1ea68404898d4b0473ff5ed9212',
#    '_index': 'famous_saying_v2',
#    '_score': 1.8788158,
#    '_source': {'content': '모범은 모든 사람이 읽을 수 있는 교훈이다.',
#     'content_length': 7,
#     'speaker': '웨스트'},
#    '_type': 'famous_saying'},
#   {'_id': 'bca4ce31f5b4a0b65ac5017fcba8421f',
#    '_index': 'famous_saying_v2',
#    '_score': 1.8788158,
#    '_source': {'content': '자신을 알 수 있는 사람이야말로 진정한 현인이다.',
#     'content_length': 7,
#     'speaker': '초서'},
#    '_type': 'famous_saying'},
#   {'_id': '9d2e331d127036c3e2308c6a4b849dcb',
#    '_index': 'famous_saying_v2',
#    '_score': 1.7226881,
#    '_source': {'content': '교육이 거둘 수 있는 최고의 성과는 관용이다',
#     'content_length': 7,
#     'speaker': '헬렌 켈러'},
#    '_type': 'famous_saying'},
#   {'_id': 'fda68beb89f85fd198f8a291d66c1498',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6945827,
#    '_source': {'content': '할 수 있는 자는 행한다. 할 수 없는 자는 가르친다',
#     'content_length': 10,
#     'speaker': '조지 버나드 쇼'},
#    '_type': 'famous_saying'},
#   {'_id': '59212831f0e8143f9769384922d485c7',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6248591,
#    '_source': {'content': '예술은 당신이 일상을 벗어날 수 있는 모든 것이다',
#     'content_length': 8,
#     'speaker': '앤디 워홀'},
#    '_type': 'famous_saying'},
#   {'_id': '4004698dca11495b053d3dd9f40aaf38',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6248591,
#    '_source': {'content': '순교는 능력 없이 유명해질 수 있는 유일한 방법이다',
#     'content_length': 8,
#     'speaker': '조지 버나드 쇼'},
#    '_type': 'famous_saying'},
#   {'_id': '54392a744ee94890af69e04216896766',
#    '_index': 'famous_saying_v2',
#    '_score': 1.6202759,
#    '_source': {'content': '미래는 검색할 수 있는 것이 아니다',
#     'content_length': 6,
#     'speaker': '윌리엄 깁슨'},
#    '_type': 'famous_saying'},
#   {'_id': 'a1e3e5fc92e24c66b1f50d7409f21b7e',
#    '_index': 'famous_saying_v2',
#    '_score': 1.5833561,
#    '_source': {'content': '자기가 할 수 있는 일은 남에게 밀지 말라.',
#     'content_length': 8,
#     'speaker': '제퍼슨'},
#    '_type': 'famous_saying'},
#   {'_id': 'a70b86603e5ad7ca75b48ffb7057242d',
#    '_index': 'famous_saying_v2',
#    '_score': 1.5833561,
#    '_source': {'content': '가장 잘 통치할 수 있는 자가 통치해야 한다',
#     'content_length': 8,
#     'speaker': '아리스토텔레스'},
#    '_type': 'famous_saying'},
#   {'_id': '6c721070b5634c5de4c8476c1ccd861d',
#    '_index': 'famous_saying_v2',
#    '_score': 1.5038409,
#    '_source': {'content': '긍지는 인간이 입을 수 있는 가장 훌륭한 갑옷이다.',
#     'content_length': 8,
#     'speaker': '제롬'},
#    '_type': 'famous_saying'},
#   {'_id': '779d0845e5ce7458bc4371b2204de242',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4672115,
#    '_source': {'content': '할 수 있는 한 훌륭한 인생을 만들라.인생은 짧고 곧 지나간다.',
#     'content_length': 10,
#     'speaker': '오울디즈'},
#    '_type': 'famous_saying'},
#   {'_id': 'ad3201de6f515ea0d50e3669aed921b9',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4672115,
#    '_source': {'content': '죽음은 인간이 받을 수 있는 축복 중 최고의 축복이다',
#     'content_length': 9,
#     'speaker': '소크라테스'},
#    '_type': 'famous_saying'},
#   {'_id': '1267e889488ecc09075d9c446d71bf4d',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4672115,
#    '_source': {'content': '우리에게는 존재하지 않는 것들을 꿈꿀 수 있는 사람들이 필요하다',
#     'content_length': 9,
#     'speaker': '존 F. 케네디'},
#    '_type': 'famous_saying'},
#   {'_id': 'd473bf9affcdf123bc3e2ccb70e12ad3',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4401805,
#    '_source': {'content': '인생에 대해 내가 말할 수 있는 전부는, 오 하나님, 즐기라는 거다!',
#     'content_length': 11,
#     'speaker': '밥 뉴하트'},
#    '_type': 'famous_saying'},
#   {'_id': '57973ab72255898f08c80fc08e4d809d',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4359425,
#    '_source': {'content': '상상력은 현실과의 전쟁에서 쓸 수 있는 무기다',
#     'content_length': 7,
#     'speaker': '쥘 드 고티에'},
#    '_type': 'famous_saying'},
#   {'_id': 'c4b2042de757e7c28839c192d5587091',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4060168,
#    '_source': {'content': '사랑은 고생을 면할 수가 없다.그러나 잊을 수 있는 능력이 있다.',
#     'content_length': 10,
#     'speaker': '디즈레일리'},
#    '_type': 'famous_saying'},
#   {'_id': '01d7015b14b65768f2513c59468ceafa',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4060168,
#    '_source': {'content': '인격은 당신의 아이들에게 남겨줄 수 있는 최대의 유산이다.',
#     'content_length': 8,
#     'speaker': '아놀드 그라소우'},
#    '_type': 'famous_saying'},
#   {'_id': '22efc478a481529ebcedeeecd2b71005',
#    '_index': 'famous_saying_v2',
#    '_score': 1.4060168,
#    '_source': {'content': '들어 옮길 수 있는 양보다 많이 먹지 말라',
#     'content_length': 8,
#     'speaker': '미스 피기'},
#    '_type': 'famous_saying'},
#   {'_id': 'a9fada90360b1741668e3c5a96cb5df2',
#    '_index': 'famous_saying_v2',
#    '_score': 1.3664114,
#    '_source': {'content': '가치있는 적이 될 수 있는 자는 화해하면 더 가치있는 친구가 될 것이다.',
#     'content_length': 12,
#     'speaker': '펠담'},
#    '_type': 'famous_saying'},
#   {'_id': 'de81075004fd35b654f147ab498d14cc',
#    '_index': 'famous_saying_v2',
#    '_score': 1.3313017,
#    '_source': {'content': '중요한 일에 집중할 수 있는 능력이 바로 지능의 가장 결정적인 특징이다',
#     'content_length': 11,
#     'speaker': '로버트 J. 쉴러'},
#    '_type': 'famous_saying'},
#   {'_id': '0217f9d4d8aef281540a7516426ff647',
#    '_index': 'famous_saying_v2',
#    '_score': 1.3195076,
#    '_source': {'content': '자신이 현명하다고 생각하고 있는 인간은 정녕 구제할 수 없는 바보이다.',
#     'content_length': 10,
#     'speaker': '볼테르'},
#    '_type': 'famous_saying'},
#   {'_id': '4d7b44305f42c21484e73f04ad675136',
#    '_index': 'famous_saying_v2',
#    '_score': 1.3195076,
#    '_source': {'content': '돈으로 살 수 있는 행복이라 불리는 상품은 없다.',
#     'content_length': 8,
#     'speaker': '헨리 밴 다이크'},
#    '_type': 'famous_saying'},
#   {'_id': '33637159069a037c8c32ff49766f604a',
#    '_index': 'famous_saying_v2',
#    '_score': 1.3195076,
#    '_source': {'content': '자신이 될 수 있는 존재가 되길 희망하는 것이 삶의 목적이다',
#     'content_length': 10,
#     'speaker': '신시아 오지크'},
#    '_type': 'famous_saying'},
#   {'_id': 'c9be0b4633c23d547028f8ad73654309',
#    '_index': 'famous_saying_v2',
#    '_score': 1.3195076,
#    '_source': {'content': '비폭력은 인류가 활용할 수 있는 가장 강력한 힘이다',
#     'content_length': 8,
#     'speaker': '마하트마 간디'},
#    '_type': 'famous_saying'},
#   {'_id': 'a1468a5d4b79726e4bff5e168f864fa7',
#    '_index': 'famous_saying_v2',
#    '_score': 1.2030728,
#    '_source': {'content': '휴대할 수 있는 것만 소유하고, 언어, 국가, 사람들을 알아라. 기억을 여행 가방 삼아라',
#     'content_length': 13,
#     'speaker': '알렉산드르 솔제니친'},
#    '_type': 'famous_saying'},
#   {'_id': 'feb994ed01d1600201ce9218db5ad467',
#    '_index': 'famous_saying_v2',
#    '_score': 1.2030728,
#    '_source': {'content': '지금이 제일 비참하다고 할 수 있는 동안은 아직 제일 비참한 게 아니다',
#     'content_length': 12,
#     'speaker': '윌리엄 셰익스피어'},
#    '_type': 'famous_saying'}])

# %%
import json
r1 = set([doc['_source']['content'] for doc in searcher.search_all('"수 있는"', field='content')['hits']['hits']])
r2 = set([doc['_source']['content'] for doc in searcher.search_all('"수" AND "있는"', field='content')['hits']['hits']])
len(r1), len(r2), r2-r1
# Out:
# (25, 26, {'자신이 현명하다고 생각하고 있는 인간은 정녕 구제할 수 없는 바보이다.'})

# %%
r = searcher.search_all('"수" OR "없는"', field='content')['hits']
r['total'], r['hits'][-5:]
# Out:
# (97,
#  [{'_id': '1fd554bd11db53081e04f124245890bd',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '소유물의 부족은 개선할 수 있으나 영혼의 가난은 해결하기 쉬운 것이 아니다.',
#     'content_length': 11,
#     'speaker': '몽테뉴'},
#    '_type': 'famous_saying'},
#   {'_id': 'ab2f1dd1f629321636721df39ee30f42',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '당신이 어떤 위험을 감수하냐를 보면, 당신이 무엇을 가치있게 여기는지 알 수 있다',
#     'content_length': 12,
#     'speaker': '자넷 윈터슨'},
#    '_type': 'famous_saying'},
#   {'_id': 'a1468a5d4b79726e4bff5e168f864fa7',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '휴대할 수 있는 것만 소유하고, 언어, 국가, 사람들을 알아라. 기억을 여행 가방 삼아라',
#     'content_length': 13,
#     'speaker': '알렉산드르 솔제니친'},
#    '_type': 'famous_saying'},
#   {'_id': 'feb994ed01d1600201ce9218db5ad467',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '지금이 제일 비참하다고 할 수 있는 동안은 아직 제일 비참한 게 아니다',
#     'content_length': 12,
#     'speaker': '윌리엄 셰익스피어'},
#    '_type': 'famous_saying'},
#   {'_id': '3c9f15c248d451c616ba9bca6cd473df',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '사람의 정신은 한 번 새로운 생각으로 늘어나게 되면 다시는 원래의 수준으로 돌아갈 수 없다',
#     'content_length': 14,
#     'speaker': '올리버 웬델 홈스'},
#    '_type': 'famous_saying'}])

# %%
r = searcher.search_all('"수" "없는"', field='content')['hits']
r['total'], r['hits'][-5:]
# Out:
# (97,
#  [{'_id': '1fd554bd11db53081e04f124245890bd',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '소유물의 부족은 개선할 수 있으나 영혼의 가난은 해결하기 쉬운 것이 아니다.',
#     'content_length': 11,
#     'speaker': '몽테뉴'},
#    '_type': 'famous_saying'},
#   {'_id': 'ab2f1dd1f629321636721df39ee30f42',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '당신이 어떤 위험을 감수하냐를 보면, 당신이 무엇을 가치있게 여기는지 알 수 있다',
#     'content_length': 12,
#     'speaker': '자넷 윈터슨'},
#    '_type': 'famous_saying'},
#   {'_id': 'a1468a5d4b79726e4bff5e168f864fa7',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '휴대할 수 있는 것만 소유하고, 언어, 국가, 사람들을 알아라. 기억을 여행 가방 삼아라',
#     'content_length': 13,
#     'speaker': '알렉산드르 솔제니친'},
#    '_type': 'famous_saying'},
#   {'_id': 'feb994ed01d1600201ce9218db5ad467',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '지금이 제일 비참하다고 할 수 있는 동안은 아직 제일 비참한 게 아니다',
#     'content_length': 12,
#     'speaker': '윌리엄 셰익스피어'},
#    '_type': 'famous_saying'},
#   {'_id': '3c9f15c248d451c616ba9bca6cd473df',
#    '_index': 'famous_saying_v1',
#    '_score': 0.21365876,
#    '_source': {'content': '사람의 정신은 한 번 새로운 생각으로 늘어나게 되면 다시는 원래의 수준으로 돌아갈 수 없다',
#     'content_length': 14,
#     'speaker': '올리버 웬델 홈스'},
#    '_type': 'famous_saying'}])

# %%
# wild card
pprint.pprint(searcher.search_all('지구', field='content')['hits']['hits'])
pprint.pprint(searcher.search_all('지구*', field='content')['hits']['hits'])
pprint.pprint(searcher.search_all('지구?', field='content')['hits']['hits'])
# Out:
# []
# [{'_id': '2b5d8b0773e505fdc32835907015f7d7',
#   '_index': 'famous_saying_v2',
#   '_score': 1.0,
#   '_source': {'content': '지구상에는 인간이외는 위대한 것이 없다.인간에게는 지성이외엔 훌륭한 것이 없다.',
#               'content_length': 9,
#               'speaker': '헤밀턴'},
#   '_type': 'famous_saying'},
#  {'_id': 'fc4f6c7cb37af9d7faf4556b351d9d97',
#   '_index': 'famous_saying_v2',
#   '_score': 1.0,
#   '_source': {'content': '천재는 지구가 절대로 길들일 수 없는 전기 같은 힘을 가졌다',
#               'content_length': 10,
#               'speaker': '리디아 M. 차일드'},
#   '_type': 'famous_saying'}]
# [{'_id': 'fc4f6c7cb37af9d7faf4556b351d9d97',
#   '_index': 'famous_saying_v2',
#   '_score': 1.0,
#   '_source': {'content': '천재는 지구가 절대로 길들일 수 없는 전기 같은 힘을 가졌다',
#               'content_length': 10,
#               'speaker': '리디아 M. 차일드'},
#   '_type': 'famous_saying'}]

# %%
# fuzziness
pprint.pprint(searcher.search_all('지구~1', field='content')['hits']['hits'])
# Out:
# [{'_id': 'b3df16497fd7c2db85c0357c9d72c0d5',
#   '_index': 'famous_saying_v1',
#   '_score': 2.1111984,
#   '_source': {'content': '인생은 다만 한 통의 살구 씨일 뿐이다',
#               'content_length': 7,
#               'speaker': '로드니 데인저필드'},
#   '_type': 'famous_saying'},
#  {'_id': '2a01ab42b11bfcca30cc3f84fe0ef817',
#   '_index': 'famous_saying_v1',
#   '_score': 2.100059,
#   '_source': {'content': '지혜 없는 힘은 그 자체의 무게로 쓰러진다',
#               'content_length': 7,
#               'speaker': '호라티우스'},
#   '_type': 'famous_saying'},
#  {'_id': '6744fdd39a7ec1bcc412785b14a3d624',
#   '_index': 'famous_saying_v1',
#   '_score': 1.7372268,
#   '_source': {'content': '지혜로운 자는 사랑하고, 다른 모든 이는 욕망할 지니',
#               'content_length': 8,
#               'speaker': '아프라니우스'},
#   '_type': 'famous_saying'},
#  {'_id': 'ace44de019469f10782c66c152a5e20d',
#   '_index': 'famous_saying_v1',
#   '_score': 1.5017462,
#   '_source': {'content': '신은 아비가 지은 죄에 대해 자식들을 처벌한다',
#               'content_length': 7,
#               'speaker': '에우리피데스'},
#   '_type': 'famous_saying'},
#  {'_id': 'fc4f6c7cb37af9d7faf4556b351d9d97',
#   '_index': 'famous_saying_v1',
#   '_score': 1.2514551,
#   '_source': {'content': '천재는 지구가 절대로 길들일 수 없는 전기 같은 힘을 가졌다',
#               'content_length': 10,
#               'speaker': '리디아 M. 차일드'},
#   '_type': 'famous_saying'}]

# %%
# proximity search
pprint.pprint(searcher.search_all('"것이 아니라"~0', field='content')['hits']['hits'])
pprint.pprint(searcher.search_all('"것이 아니라"~1', field='content')['hits']['hits'])
# Out:
# [{'_id': 'f673c6b4af1d0848816f4b2ba7c831f3',
#   '_index': 'famous_saying_v1',
#   '_score': 3.5504873,
#   '_source': {'content': '민주주의는 정지된 것이 아니라 영원히 계속되는 행진이다.',
#               'content_length': 7,
#               'speaker': '루즈벨트'},
#   '_type': 'famous_saying'},
#  {'_id': '0c2e591d45e0a7e2bf2a24384bf196e9',
#   '_index': 'famous_saying_v1',
#   '_score': 2.9587393,
#   '_source': {'content': '좋은 집이란 구입하는 것이 아니라 만들어지는 것이어야 한다',
#               'content_length': 8,
#               'speaker': '조이스 메이나드'},
#   '_type': 'famous_saying'},
#  {'_id': 'f1fcdc3ccab32ee16b9b2d78485cd50a',
#   '_index': 'famous_saying_v1',
#   '_score': 2.909992,
#   '_source': {'content': '중요한 것은 사랑을 받는 것이 아니라 사랑을 하는 것이었다',
#               'content_length': 9,
#               'speaker': '서머셋 모옴'},
#   '_type': 'famous_saying'}]
# [{'_id': 'f673c6b4af1d0848816f4b2ba7c831f3',
#   '_index': 'famous_saying_v1',
#   '_score': 3.5504873,
#   '_source': {'content': '민주주의는 정지된 것이 아니라 영원히 계속되는 행진이다.',
#               'content_length': 7,
#               'speaker': '루즈벨트'},
#   '_type': 'famous_saying'},
#  {'_id': '0c2e591d45e0a7e2bf2a24384bf196e9',
#   '_index': 'famous_saying_v1',
#   '_score': 2.9587393,
#   '_source': {'content': '좋은 집이란 구입하는 것이 아니라 만들어지는 것이어야 한다',
#               'content_length': 8,
#               'speaker': '조이스 메이나드'},
#   '_type': 'famous_saying'},
#  {'_id': 'f1fcdc3ccab32ee16b9b2d78485cd50a',
#   '_index': 'famous_saying_v1',
#   '_score': 2.909992,
#   '_source': {'content': '중요한 것은 사랑을 받는 것이 아니라 사랑을 하는 것이었다',
#               'content_length': 9,
#               'speaker': '서머셋 모옴'},
#   '_type': 'famous_saying'},
#  {'_id': '6048fffb7e4f002eaaee9e020dd52988',
#   '_index': 'famous_saying_v1',
#   '_score': 2.129056,
#   '_source': {'content': '신기한 말을 하는 것이 귀함이 아니라 실행함이 귀하다.',
#               'content_length': 8,
#               'speaker': '이태백'},
#   '_type': 'famous_saying'}]
